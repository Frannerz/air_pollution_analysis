# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from datetime import datetime, timedelta
import time
import json
import statistics
import seaborn as sns
import csv

# %% [markdown]
# ## Information on Air Quality measurements

# %%
pollutant_data = {
    "Qualitative name": ["Good", "Fair", "Moderate", "Poor", "Very Poor"],
    "AQ Index": list(range(1, 6)),
    "CO": ["[0; 4400)", "[4400; 9400)", "[9400-12400)", "[12400; 15400)", "⩾15400"],
    "NO2": ["[0; 40)", "[40; 70)", "[70; 150)", "[150; 200)", "⩾200"],
    "O3": ["[0; 60)", "[60; 100)", "[100; 140)", "[140; 180)", "⩾180"],
    "PM2.5": ["[0; 10)", "[10; 25)", "[25; 50)", "[50; 75)", "⩾75"],
    "PM10": ["[0; 20)", "[20; 50)", "[50; 100)", "[100; 200)", "⩾200"],
    "SO2": ["[0; 20)", "[20; 80)", "[80; 250)", "[250; 350)", "⩾350"]
}


pollutant_levels = pd.DataFrame(pollutant_data)


print('UK Annual mean NO2 target: 40')
print('WHO NO2 target: 10')
# https://www.gov.uk/government/statistics/air-quality-statistics/ntrogen-dioxide
# https://www.who.int/news-room/feature-stories/detail/what-are-the-who-air-quality-guidelines
# Out:
# UK Annual mean NO2 target: 40
# WHO NO2 target: 10

# %%
pollutant_levels
# Out:
#   Qualitative name  AQ Index              CO         NO2          O3  \
# 0             Good         1       [0; 4400)     [0; 40)     [0; 60)
# 1             Fair         2    [4400; 9400)    [40; 70)   [60; 100)
# 2         Moderate         3    [9400-12400)   [70; 150)  [100; 140)
# 3             Poor         4  [12400; 15400)  [150; 200)  [140; 180)
# 4        Very Poor         5          ⩾15400        ⩾200        ⩾180
#
#       PM2.5        PM10         SO2
# 0   [0; 10)     [0; 20)     [0; 20)
# 1  [10; 25)    [20; 50)    [20; 80)
# 2  [25; 50)   [50; 100)   [80; 250)
# 3  [50; 75)  [100; 200)  [250; 350)
# 4       ⩾75        ⩾200        ⩾350

# %%
# %%html
# <style>
#     .purple {
#         background-color: #e6ccff;
#     }
#     .green {
#         background-color: #99ffdd;
#     }
#     .blue {
#         background-color: #b3f0ff;
#     }
#     .center {
#         text-align: center;
#     }
#     .extra-padding {
#         padding: 20px;
#     }
# </style>
# Out:
# <style>
#     .purple {
#         background-color: #e6ccff;
#     }
#     .green {
#         background-color: #99ffdd;
#     }
#     .blue {
#         background-color: #b3f0ff;
#     }
#     .center {
#         text-align: center;
#     }
#     .extra-padding {
#         padding: 20px;
#     }
# </style>

# %% [markdown]
# <div class="green extra-padding">
# <h1>Current Data for Hammersmith:</h1>
#
# - Hammersmith is one of the London Boroughs with the most polluting roads
# - There are a number of schools and hospitals within close proximity of these roads
# - Hammersmith was part of the original ULEZ scheme from 2021
# - We will mainly focus on levels of no2 and pm2.5 in this analysis but will also look at correlations with other pollutants
#
# </div>

# %% [markdown]
# ## Retrieve data using API

# %%
# These sections are commented out as the data has already been retrieved using the API
# Please load data from the saved csv 
# To test the API response, please enter and API key below

# Hammersmith coords for school near A4
# lat= '51.493096'
# lon= '-0.224079'

# API = 'ADD_API_KEY_HERE'

# # Past 3 years 
# end_date = datetime(2024, 1, 1, 12, 00, 00)
# start_date = end_date - timedelta(days=1095)

# start = int(start_date.timestamp())
# end = int(end_date.timestamp())

# response = requests.get(f'http://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={API}')


# # Check response success
# if response.status_code == 200:
#     data = response.json()
# else:
#     print(f"Error: {response.status_code}")

# %% [markdown]
# ### Save data to csv

# %%
# Data already saved
# file_path = "../data_unclean/air_pollution_data_hammersmith_3_years.csv"

# def save_to_csv(response, file_path):
#     records = []
#     for entry in response['list']:
#         record = {
#             "date_time": entry["dt"],
#             "aqi": entry["main"]["aqi"],
#             "co": entry["components"]["co"],
#             "no": entry["components"]["no"],
#             "no2": entry["components"]["no2"],
#             "o3": entry["components"]["o3"],
#             "so2": entry["components"]["so2"],
#             "pm2_5": entry["components"]["pm2_5"],
#             "pm10": entry["components"]["pm10"],
#             "nh3": entry["components"]["nh3"],
#         }
#         records.append(record)
#     aq_df = pd.DataFrame(records)
#     path = file_path
#     aq_df.to_csv(path, index=False)
#     return aq_df

# save_to_csv(response.json(), file_path)

# %% [markdown]
# ## Load data from CSV

# %%
air_quality_hammersmith = pd.read_csv('../data_unclean/air_pollution_data_hammersmith_3_years.csv')
air_quality_hammersmith.head(10)
# Out:
#     date_time  aqi      co     no    no2    o3    so2  pm2_5   pm10   nh3
# 0  1609502400    2  320.44  13.19  46.61  2.33  28.61  16.74  17.83  1.98
# 1  1609506000    2  323.77  15.65  43.87  2.12  24.08  16.56  17.74  1.44
# 2  1609509600    2  323.77  17.43  43.18  1.43  21.22  15.27  16.50  1.24
# 3  1609513200    2  327.11  18.33  44.55  0.65  19.31  13.24  14.59  1.03
# 4  1609516800    2  330.45  17.43  45.93  0.10  17.41  10.69  12.15  0.82
# 5  1609520400    2  323.77  14.53  47.30  0.04  15.74   7.85   9.31  0.71
# 6  1609524000    2  310.42  11.06  49.35  0.26  14.66   6.31   7.63  0.66
# 7  1609527600    2  307.08   8.61  50.72  0.68  15.14   6.21   7.32  0.62
# 8  1609531200    2  310.42   6.87  49.35  1.11  15.74   6.32   7.38  0.59
# 9  1609534800    2  303.75   4.92  45.24  1.97  15.14   6.00   7.15  0.56

# %%
air_quality_hammersmith.tail(10)
# Out:
#         date_time  aqi      co    no    no2     o3   so2  pm2_5  pm10   nh3
# 26007  1704078000    2  233.65  0.00   2.25  67.23  1.42   0.50  0.83  0.20
# 26008  1704081600    2  233.65  0.00   2.46  67.23  1.61   0.50  0.86  0.21
# 26009  1704085200    2  233.65  0.00   2.78  66.52  1.86   0.50  0.90  0.24
# 26010  1704088800    2  233.65  0.00   3.47  67.23  2.21   0.50  0.93  0.29
# 26011  1704092400    2  240.33  0.00   6.17  65.80  3.13   0.55  1.07  0.40
# 26012  1704096000    2  240.33  0.00   9.42  63.66  3.87   0.72  1.39  0.52
# 26013  1704099600    2  240.33  0.01  10.88  64.37  4.29   0.81  1.65  0.62
# 26014  1704103200    2  236.99  0.08  10.37  70.10  4.29   0.80  1.69  0.67
# 26015  1704106800    2  236.99  0.21   9.08  75.10  3.99   0.68  1.44  0.67
# 26016  1704110400    2  233.65  0.30   7.97  77.96  3.61   0.57  1.13  0.63

# %% [markdown]
# ## Change datetime to readable format

# %%
air_quality_hammersmith['date_time'] = pd.to_datetime(air_quality_hammersmith['date_time'], unit='s')
air_quality_hammersmith.head(10)
# Out:
#             date_time  aqi      co     no    no2    o3    so2  pm2_5   pm10  \
# 0 2021-01-01 12:00:00    2  320.44  13.19  46.61  2.33  28.61  16.74  17.83
# 1 2021-01-01 13:00:00    2  323.77  15.65  43.87  2.12  24.08  16.56  17.74
# 2 2021-01-01 14:00:00    2  323.77  17.43  43.18  1.43  21.22  15.27  16.50
# 3 2021-01-01 15:00:00    2  327.11  18.33  44.55  0.65  19.31  13.24  14.59
# 4 2021-01-01 16:00:00    2  330.45  17.43  45.93  0.10  17.41  10.69  12.15
# 5 2021-01-01 17:00:00    2  323.77  14.53  47.30  0.04  15.74   7.85   9.31
# 6 2021-01-01 18:00:00    2  310.42  11.06  49.35  0.26  14.66   6.31   7.63
# 7 2021-01-01 19:00:00    2  307.08   8.61  50.72  0.68  15.14   6.21   7.32
# 8 2021-01-01 20:00:00    2  310.42   6.87  49.35  1.11  15.74   6.32   7.38
# 9 2021-01-01 21:00:00    2  303.75   4.92  45.24  1.97  15.14   6.00   7.15
#
#     nh3
# 0  1.98
# 1  1.44
# 2  1.24
# 3  1.03
# 4  0.82
# 5  0.71
# 6  0.66
# 7  0.62
# 8  0.59
# 9  0.56

# %%
air_quality_hammersmith.tail(10)
# Out:
#                 date_time  aqi      co    no    no2     o3   so2  pm2_5  pm10  \
# 26007 2024-01-01 03:00:00    2  233.65  0.00   2.25  67.23  1.42   0.50  0.83
# 26008 2024-01-01 04:00:00    2  233.65  0.00   2.46  67.23  1.61   0.50  0.86
# 26009 2024-01-01 05:00:00    2  233.65  0.00   2.78  66.52  1.86   0.50  0.90
# 26010 2024-01-01 06:00:00    2  233.65  0.00   3.47  67.23  2.21   0.50  0.93
# 26011 2024-01-01 07:00:00    2  240.33  0.00   6.17  65.80  3.13   0.55  1.07
# 26012 2024-01-01 08:00:00    2  240.33  0.00   9.42  63.66  3.87   0.72  1.39
# 26013 2024-01-01 09:00:00    2  240.33  0.01  10.88  64.37  4.29   0.81  1.65
# 26014 2024-01-01 10:00:00    2  236.99  0.08  10.37  70.10  4.29   0.80  1.69
# 26015 2024-01-01 11:00:00    2  236.99  0.21   9.08  75.10  3.99   0.68  1.44
# 26016 2024-01-01 12:00:00    2  233.65  0.30   7.97  77.96  3.61   0.57  1.13
#
#         nh3
# 26007  0.20
# 26008  0.21
# 26009  0.24
# 26010  0.29
# 26011  0.40
# 26012  0.52
# 26013  0.62
# 26014  0.67
# 26015  0.67
# 26016  0.63

# %% [markdown]
# <h2 class="purple extra-padding">Load weather data (CSV downloaded from Open Meteo)</h2>

# %%
# Retrieved from https://open-meteo.com/en/docs/historical-weather-api#latitude=51.4938&longitude=-0.2276&start_date=2021-01-01&end_date=2024-01-01&hourly=temperature_2m,relative_humidity_2m,precipitation,rain,snowfall,surface_pressure,wind_speed_10m,wind_speed_100m,wind_direction_10m

# %%
weather_data = pd.read_csv('../data_unclean/weather_hammersmith.csv')
weather_data.head(10)
# Out:
#                time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0  2021-01-01T00:00                 -0.1                        96
# 1  2021-01-01T01:00                 -0.7                        97
# 2  2021-01-01T02:00                 -1.1                        98
# 3  2021-01-01T03:00                 -1.7                        97
# 4  2021-01-01T04:00                 -2.3                        97
# 5  2021-01-01T05:00                 -1.5                        97
# 6  2021-01-01T06:00                 -0.9                        98
# 7  2021-01-01T07:00                 -1.1                       100
# 8  2021-01-01T08:00                 -1.0                        99
# 9  2021-01-01T09:00                 -0.9                        97
#
#    precipitation (mm)  rain (mm)  snowfall (cm)  surface_pressure (hPa)  \
# 0                 0.0        0.0            0.0                  1007.8
# 1                 0.0        0.0            0.0                  1008.0
# 2                 0.0        0.0            0.0                  1008.3
# 3                 0.0        0.0            0.0                  1008.7
# 4                 0.0        0.0            0.0                  1008.7
# 5                 0.0        0.0            0.0                  1008.8
# 6                 0.0        0.0            0.0                  1008.8
# 7                 0.0        0.0            0.0                  1009.4
# 8                 0.0        0.0            0.0                  1009.8
# 9                 0.0        0.0            0.0                  1010.2
#
#    wind_speed_10m (km/h)  wind_speed_100m (km/h)  wind_direction_10m (°)
# 0                    3.8                     7.6                     253
# 1                    4.7                    10.5                     261
# 2                    5.0                    12.7                     270
# 3                    6.1                    14.0                     270
# 4                    6.9                    14.7                     279
# 5                    5.2                    14.0                     282
# 6                    6.5                    13.0                     270
# 7                    7.6                    14.2                     275
# 8                    8.8                    12.9                     282
# 9                    9.1                    11.9                     279

# %%
weather_data.time = pd.to_datetime(weather_data.time)
weather_data.head(10)
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2021-01-01 00:00:00                 -0.1                        96
# 1 2021-01-01 01:00:00                 -0.7                        97
# 2 2021-01-01 02:00:00                 -1.1                        98
# 3 2021-01-01 03:00:00                 -1.7                        97
# 4 2021-01-01 04:00:00                 -2.3                        97
# 5 2021-01-01 05:00:00                 -1.5                        97
# 6 2021-01-01 06:00:00                 -0.9                        98
# 7 2021-01-01 07:00:00                 -1.1                       100
# 8 2021-01-01 08:00:00                 -1.0                        99
# 9 2021-01-01 09:00:00                 -0.9                        97
#
#    precipitation (mm)  rain (mm)  snowfall (cm)  surface_pressure (hPa)  \
# 0                 0.0        0.0            0.0                  1007.8
# 1                 0.0        0.0            0.0                  1008.0
# 2                 0.0        0.0            0.0                  1008.3
# 3                 0.0        0.0            0.0                  1008.7
# 4                 0.0        0.0            0.0                  1008.7
# 5                 0.0        0.0            0.0                  1008.8
# 6                 0.0        0.0            0.0                  1008.8
# 7                 0.0        0.0            0.0                  1009.4
# 8                 0.0        0.0            0.0                  1009.8
# 9                 0.0        0.0            0.0                  1010.2
#
#    wind_speed_10m (km/h)  wind_speed_100m (km/h)  wind_direction_10m (°)
# 0                    3.8                     7.6                     253
# 1                    4.7                    10.5                     261
# 2                    5.0                    12.7                     270
# 3                    6.1                    14.0                     270
# 4                    6.9                    14.7                     279
# 5                    5.2                    14.0                     282
# 6                    6.5                    13.0                     270
# 7                    7.6                    14.2                     275
# 8                    8.8                    12.9                     282
# 9                    9.1                    11.9                     279

# %% [markdown]
# <h2 class="purple extra-padding">Merge weather and air quality data and get overview</h2>

# %%
weather_aq = pd.merge(air_quality_hammersmith, weather_data, left_on='date_time',right_on='time', how='left')

# %%
weather_aq.head(10)
# Out:
#             date_time  aqi      co     no    no2    o3    so2  pm2_5   pm10  \
# 0 2021-01-01 12:00:00    2  320.44  13.19  46.61  2.33  28.61  16.74  17.83
# 1 2021-01-01 13:00:00    2  323.77  15.65  43.87  2.12  24.08  16.56  17.74
# 2 2021-01-01 14:00:00    2  323.77  17.43  43.18  1.43  21.22  15.27  16.50
# 3 2021-01-01 15:00:00    2  327.11  18.33  44.55  0.65  19.31  13.24  14.59
# 4 2021-01-01 16:00:00    2  330.45  17.43  45.93  0.10  17.41  10.69  12.15
# 5 2021-01-01 17:00:00    2  323.77  14.53  47.30  0.04  15.74   7.85   9.31
# 6 2021-01-01 18:00:00    2  310.42  11.06  49.35  0.26  14.66   6.31   7.63
# 7 2021-01-01 19:00:00    2  307.08   8.61  50.72  0.68  15.14   6.21   7.32
# 8 2021-01-01 20:00:00    2  310.42   6.87  49.35  1.11  15.74   6.32   7.38
# 9 2021-01-01 21:00:00    2  303.75   4.92  45.24  1.97  15.14   6.00   7.15
#
#     nh3                time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0  1.98 2021-01-01 12:00:00                  1.4                        92
# 1  1.44 2021-01-01 13:00:00                  2.1                        91
# 2  1.24 2021-01-01 14:00:00                  2.5                        91
# 3  1.03 2021-01-01 15:00:00                  2.8                        92
# 4  0.82 2021-01-01 16:00:00                  2.7                        95
# 5  0.71 2021-01-01 17:00:00                  3.2                        94
# 6  0.66 2021-01-01 18:00:00                  3.5                        94
# 7  0.62 2021-01-01 19:00:00                  3.7                        94
# 8  0.59 2021-01-01 20:00:00                  4.0                        94
# 9  0.56 2021-01-01 21:00:00                  4.1                        94
#
#    precipitation (mm)  rain (mm)  snowfall (cm)  surface_pressure (hPa)  \
# 0                 0.0        0.0            0.0                  1010.4
# 1                 0.0        0.0            0.0                  1010.0
# 2                 0.0        0.0            0.0                  1010.0
# 3                 0.0        0.0            0.0                  1010.1
# 4                 0.0        0.0            0.0                  1010.5
# 5                 0.0        0.0            0.0                  1010.6
# 6                 0.0        0.0            0.0                  1011.0
# 7                 0.2        0.2            0.0                  1011.4
# 8                 0.2        0.2            0.0                  1011.9
# 9                 0.0        0.0            0.0                  1012.5
#
#    wind_speed_10m (km/h)  wind_speed_100m (km/h)  wind_direction_10m (°)
# 0                    8.3                    10.5                     265
# 1                    9.4                    11.9                     270
# 2                    9.4                    12.6                     263
# 3                    8.3                    13.3                     252
# 4                    6.5                    15.0                     267
# 5                    6.8                    15.9                     288
# 6                    7.7                    17.3                     307
# 7                    8.4                    18.8                     329
# 8                    9.4                    20.3                     337
# 9                   10.0                    21.5                     345

# %%
weather_aq.tail(10)
# Out:
#                 date_time  aqi      co    no    no2     o3   so2  pm2_5  pm10  \
# 26007 2024-01-01 03:00:00    2  233.65  0.00   2.25  67.23  1.42   0.50  0.83
# 26008 2024-01-01 04:00:00    2  233.65  0.00   2.46  67.23  1.61   0.50  0.86
# 26009 2024-01-01 05:00:00    2  233.65  0.00   2.78  66.52  1.86   0.50  0.90
# 26010 2024-01-01 06:00:00    2  233.65  0.00   3.47  67.23  2.21   0.50  0.93
# 26011 2024-01-01 07:00:00    2  240.33  0.00   6.17  65.80  3.13   0.55  1.07
# 26012 2024-01-01 08:00:00    2  240.33  0.00   9.42  63.66  3.87   0.72  1.39
# 26013 2024-01-01 09:00:00    2  240.33  0.01  10.88  64.37  4.29   0.81  1.65
# 26014 2024-01-01 10:00:00    2  236.99  0.08  10.37  70.10  4.29   0.80  1.69
# 26015 2024-01-01 11:00:00    2  236.99  0.21   9.08  75.10  3.99   0.68  1.44
# 26016 2024-01-01 12:00:00    2  233.65  0.30   7.97  77.96  3.61   0.57  1.13
#
#         nh3                time  temperature_2m (°C)  \
# 26007  0.20 2024-01-01 03:00:00                  7.0
# 26008  0.21 2024-01-01 04:00:00                  6.8
# 26009  0.24 2024-01-01 05:00:00                  6.8
# 26010  0.29 2024-01-01 06:00:00                  6.5
# 26011  0.40 2024-01-01 07:00:00                  6.3
# 26012  0.52 2024-01-01 08:00:00                  5.9
# 26013  0.62 2024-01-01 09:00:00                  6.4
# 26014  0.67 2024-01-01 10:00:00                  7.1
# 26015  0.67 2024-01-01 11:00:00                  7.8
# 26016  0.63 2024-01-01 12:00:00                  8.4
#
#        relative_humidity_2m (%)  precipitation (mm)  rain (mm)  snowfall (cm)  \
# 26007                        80                 0.0        0.0            0.0
# 26008                        79                 0.0        0.0            0.0
# 26009                        75                 0.0        0.0            0.0
# 26010                        74                 0.0        0.0            0.0
# 26011                        71                 0.0        0.0            0.0
# 26012                        71                 0.0        0.0            0.0
# 26013                        69                 0.0        0.0            0.0
# 26014                        69                 0.0        0.0            0.0
# 26015                        69                 0.0        0.0            0.0
# 26016                        68                 0.0        0.0            0.0
#
#        surface_pressure (hPa)  wind_speed_10m (km/h)  wind_speed_100m (km/h)  \
# 26007                   996.8                   26.0                    42.7
# 26008                   997.8                   26.2                    43.3
# 26009                   998.5                   26.0                    43.3
# 26010                   999.4                   24.9                    41.8
# 26011                  1000.5                   22.9                    39.4
# 26012                  1001.5                   19.6                    35.5
# 26013                  1002.3                   19.3                    34.1
# 26014                  1002.7                   19.1                    31.7
# 26015                  1003.2                   18.2                    29.4
# 26016                  1003.1                   16.6                    25.6
#
#        wind_direction_10m (°)
# 26007                     251
# 26008                     252
# 26009                     256
# 26010                     256
# 26011                     257
# 26012                     256
# 26013                     256
# 26014                     248
# 26015                     236
# 26016                     228

# %%
weather_aq['aqi'].value_counts()
# Out:
# aqi
# 1    14572
# 2     9317
# 3     1344
# 4      681
# 5      103
# Name: count, dtype: int64

# %%
weather_aq['aqi'].value_counts(normalize=True)
# Out:
# aqi
# 1    0.560095
# 2    0.358112
# 3    0.051659
# 4    0.026175
# 5    0.003959
# Name: proportion, dtype: float64

# %% [markdown]
# Air quality in Hammersmith is rated 'good' 56% of the time, 44% of the time fair or below.
# It is 'poor' or 'moderate' over 7% of the time and 'very poor' less than one percent of the time.

# %%
weather_aq.columns
# Out:
# Index(['date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'time', 'temperature_2m (°C)', 'relative_humidity_2m (%)',
#        'precipitation (mm)', 'rain (mm)', 'snowfall (cm)',
#        'surface_pressure (hPa)', 'wind_speed_10m (km/h)',
#        'wind_speed_100m (km/h)', 'wind_direction_10m (°)'],
#       dtype='object')

# %%
weather_aq.shape
# Out:
# (26017, 20)

# %%
weather_aq.dtypes
# Out:
# date_time                   datetime64[ns]
# aqi                                  int64
# co                                 float64
# no                                 float64
# no2                                float64
# o3                                 float64
# so2                                float64
# pm2_5                              float64
# pm10                               float64
# nh3                                float64
# time                        datetime64[ns]
# temperature_2m (°C)                float64
# relative_humidity_2m (%)             int64
# precipitation (mm)                 float64
# rain (mm)                          float64
# snowfall (cm)                      float64
# surface_pressure (hPa)             float64
# wind_speed_10m (km/h)              float64
# wind_speed_100m (km/h)             float64
# wind_direction_10m (°)               int64
# dtype: object

# %%
weather_aq = weather_aq.drop(columns='time')

# %%
weather_aq.columns
# Out:
# Index(['date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'temperature_2m (°C)', 'relative_humidity_2m (%)',
#        'precipitation (mm)', 'rain (mm)', 'snowfall (cm)',
#        'surface_pressure (hPa)', 'wind_speed_10m (km/h)',
#        'wind_speed_100m (km/h)', 'wind_direction_10m (°)'],
#       dtype='object')

# %% [markdown]
# ## Rename columns

# %%
weather_aq = weather_aq.rename(columns = {
    'temperature_2m (°C)':'temp_C', 
    'relative_humidity_2m (%)': 'percent_humidity',
    'precipitation (mm)':'precipitation',
    'rain (mm)': 'rain',
    'snowfall (cm)': 'snowfall',
    'surface_pressure (hPa)':'surface_pressure',
    'wind_speed_10m (km/h)': 'wind_speed_10m',
    'wind_speed_100m (km/h)':'wind_speed_100m',
    'wind_direction_10m (°)':'wind_direction'
})

# %%
weather_aq.columns
# Out:
# Index(['date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'temp_C', 'percent_humidity', 'precipitation', 'rain',
#        'snowfall', 'surface_pressure', 'wind_speed_10m', 'wind_speed_100m',
#        'wind_direction'],
#       dtype='object')

# %% [markdown]
# ## Create new columns: day, time, month

# %%
weather_aq['day'] = weather_aq['date_time'].dt.dayofweek
# The day of the week with Monday=0, Sunday=6.

# %%
weather_aq['month'] = weather_aq['date_time'].dt.month

# %%
weather_aq['hour'] = weather_aq['date_time'].dt.hour

# %%
weather_aq.head(20)
# Out:
#              date_time  aqi      co     no    no2     o3    so2  pm2_5   pm10  \
# 0  2021-01-01 12:00:00    2  320.44  13.19  46.61   2.33  28.61  16.74  17.83
# 1  2021-01-01 13:00:00    2  323.77  15.65  43.87   2.12  24.08  16.56  17.74
# 2  2021-01-01 14:00:00    2  323.77  17.43  43.18   1.43  21.22  15.27  16.50
# 3  2021-01-01 15:00:00    2  327.11  18.33  44.55   0.65  19.31  13.24  14.59
# 4  2021-01-01 16:00:00    2  330.45  17.43  45.93   0.10  17.41  10.69  12.15
# 5  2021-01-01 17:00:00    2  323.77  14.53  47.30   0.04  15.74   7.85   9.31
# 6  2021-01-01 18:00:00    2  310.42  11.06  49.35   0.26  14.66   6.31   7.63
# 7  2021-01-01 19:00:00    2  307.08   8.61  50.72   0.68  15.14   6.21   7.32
# 8  2021-01-01 20:00:00    2  310.42   6.87  49.35   1.11  15.74   6.32   7.38
# 9  2021-01-01 21:00:00    2  303.75   4.92  45.24   1.97  15.14   6.00   7.15
# 10 2021-01-01 22:00:00    2  300.41   3.27  41.13   3.53  14.31   5.68   6.92
# 11 2021-01-01 23:00:00    1  290.39   1.82  37.70   6.17  13.11   5.24   6.62
# 12 2021-01-02 00:00:00    1  273.71   0.50  31.19  12.52  10.73   4.44   5.83
# 13 2021-01-02 01:00:00    1  257.02   0.11  23.65  20.74   8.23   3.90   5.36
# 14 2021-01-02 02:00:00    1  250.34   0.05  19.36  25.75   6.97   3.76   5.25
# 15 2021-01-02 03:00:00    1  247.00   0.04  17.65  27.54   6.80   3.70   5.13
# 16 2021-01-02 04:00:00    1  247.00   0.04  16.97  27.90   6.86   3.57   4.85
# 17 2021-01-02 05:00:00    1  247.00   0.05  16.97  27.54   7.21   3.40   4.51
# 18 2021-01-02 06:00:00    1  250.34   0.08  18.51  25.03   7.99   3.37   4.39
# 19 2021-01-02 07:00:00    1  260.35   0.35  25.02  18.77  10.01   4.18   5.27
#
#      nh3  ...  precipitation  rain  snowfall  surface_pressure  \
# 0   1.98  ...            0.0   0.0       0.0            1010.4
# 1   1.44  ...            0.0   0.0       0.0            1010.0
# 2   1.24  ...            0.0   0.0       0.0            1010.0
# 3   1.03  ...            0.0   0.0       0.0            1010.1
# 4   0.82  ...            0.0   0.0       0.0            1010.5
# 5   0.71  ...            0.0   0.0       0.0            1010.6
# 6   0.66  ...            0.0   0.0       0.0            1011.0
# 7   0.62  ...            0.2   0.2       0.0            1011.4
# 8   0.59  ...            0.2   0.2       0.0            1011.9
# 9   0.56  ...            0.0   0.0       0.0            1012.5
# 10  0.53  ...            0.0   0.0       0.0            1013.0
# 11  0.48  ...            0.0   0.0       0.0            1013.2
# 12  0.37  ...            0.0   0.0       0.0            1013.3
# 13  0.29  ...            0.0   0.0       0.0            1013.4
# 14  0.25  ...            0.0   0.0       0.0            1013.7
# 15  0.24  ...            0.0   0.0       0.0            1013.9
# 16  0.22  ...            0.0   0.0       0.0            1013.8
# 17  0.22  ...            0.0   0.0       0.0            1013.9
# 18  0.25  ...            0.0   0.0       0.0            1014.2
# 19  0.34  ...            0.0   0.0       0.0            1014.7
#
#     wind_speed_10m  wind_speed_100m  wind_direction  day  month  hour
# 0              8.3             10.5             265    4      1    12
# 1              9.4             11.9             270    4      1    13
# 2              9.4             12.6             263    4      1    14
# 3              8.3             13.3             252    4      1    15
# 4              6.5             15.0             267    4      1    16
# 5              6.8             15.9             288    4      1    17
# 6              7.7             17.3             307    4      1    18
# 7              8.4             18.8             329    4      1    19
# 8              9.4             20.3             337    4      1    20
# 9             10.0             21.5             345    4      1    21
# 10             9.8             19.8             343    4      1    22
# 11            10.2             19.9             342    4      1    23
# 12             7.4             17.0             331    5      1     0
# 13             8.5             18.1             332    5      1     1
# 14            12.0             22.4             339    5      1     2
# 15            12.3             22.5             339    5      1     3
# 16            12.6             22.8             336    5      1     4
# 17            13.0             23.9             341    5      1     5
# 18            11.8             22.3             340    5      1     6
# 19            13.2             23.6             338    5      1     7
#
# [20 rows x 22 columns]

# %% [markdown]
# ## Look for missing/ anomalous data

# %%
weather_aq.describe()
# Out:
#                            date_time           aqi            co  \
# count                          26017  26017.000000  26017.000000
# mean   2022-07-02 09:44:53.669523712      1.555790    249.606006
# min              2021-01-01 12:00:00      1.000000    141.860000
# 25%              2021-09-30 12:00:00      1.000000    205.280000
# 50%              2022-06-30 12:00:00      1.000000    233.650000
# 75%              2023-04-04 12:00:00      2.000000    270.370000
# max              2024-01-01 12:00:00      5.000000   1268.390000
# std                              NaN      0.744838     80.892569
#
#                  no           no2            o3           so2         pm2_5  \
# count  26017.000000  26017.000000  26017.000000  26017.000000  26017.000000
# mean       6.358509     18.793544     50.661807      7.872453      6.815382
# min        0.000000      1.340000  -9999.000000      0.860000      0.500000
# 25%        0.000000      7.800000     30.400000      3.810000      2.230000
# 50%        0.290000     13.370000     53.640000      5.660000      3.990000
# 75%        1.500000     23.990000     70.810000      9.060000      7.760000
# max      447.030000    126.120000    205.990000    129.700000    104.540000
# std       23.804967     15.823728     69.255641      7.844575      8.264211
#
#                pm10           nh3  ...  precipitation          rain  \
# count  26017.000000  26017.000000  ...   26017.000000  26017.000000
# mean       8.654816      0.885957  ...       0.085175      0.084126
# min        0.530000      0.000000  ...       0.000000      0.000000
# 25%        3.310000      0.290000  ...       0.000000      0.000000
# 50%        5.870000      0.550000  ...       0.000000      0.000000
# 75%       10.420000      1.040000  ...       0.000000      0.000000
# max      108.950000     15.200000  ...      14.700000     14.700000
# std        8.995321      1.104444  ...       0.373876      0.372101
#
#            snowfall  surface_pressure  wind_speed_10m  wind_speed_100m  \
# count  26017.000000      26017.000000    26017.000000     26017.000000
# mean       0.000735       1014.434466       14.640931        24.320202
# min        0.000000        952.700000        0.000000         0.000000
# 25%        0.000000       1007.800000        8.800000        16.500000
# 50%        0.000000       1015.500000       13.200000        23.200000
# 75%        0.000000       1022.100000       19.200000        30.800000
# max        1.400000       1044.700000       68.000000        99.800000
# std        0.018808         11.136033        7.555999        11.249840
#
#        wind_direction           day         month          hour
# count    26017.000000  26017.000000  26017.000000  26017.000000
# mean       190.313334      2.991967      6.530192     11.500019
# min          1.000000      0.000000      1.000000      0.000000
# 25%        102.000000      1.000000      4.000000      6.000000
# 50%        217.000000      3.000000      7.000000     12.000000
# 75%        253.000000      5.000000     10.000000     17.000000
# max        360.000000      6.000000     12.000000     23.000000
# std         93.849017      2.002452      3.436163      6.922187
#
# [8 rows x 22 columns]

# %% [markdown]
# <h2 class="purple extra-padding">Observations/ dealing with anomalous values</h2>

# %% [markdown]
# ### Variance
# - There is a large amount of variance within most of the pollutant data apart from that of Ammonia (nh3)
# - The highest values of no2 and pm2.5 (our main focus of the report) are well over that of the recommended level (no2 is 3x UK target and pm2.5 is 10x UK target)

# %% [markdown]
# ### Negative values
# There are some negative values in the o3 data which is impossible. These will be counted and dealt with.

# %%
negative_values = weather_aq[weather_aq.o3 < 0]
len(negative_values)
# Out:
# 1

# %%
# As there is only 1 negative value, this row can be deleted
weather_aq = weather_aq[weather_aq.o3 >= 0]
weather_aq.describe()
# Out:
#                            date_time           aqi            co  \
# count                          26016  26016.000000  26016.000000
# mean   2022-07-02 09:23:22.167896576      1.555812    249.608223
# min              2021-01-01 12:00:00      1.000000    141.860000
# 25%              2021-09-30 11:45:00      1.000000    205.280000
# 50%              2022-06-30 11:30:00      1.000000    233.650000
# 75%              2023-04-04 11:15:00      2.000000    270.370000
# max              2024-01-01 12:00:00      5.000000   1268.390000
# std                              NaN      0.744845     80.893333
#
#                  no           no2            o3           so2         pm2_5  \
# count  26016.000000  26016.000000  26016.000000  26016.000000  26016.000000
# mean       6.358238     18.793687     51.048095      7.872474      6.815534
# min        0.000000      1.340000      0.000000      0.860000      0.500000
# 25%        0.000000      7.800000     30.400000      3.810000      2.230000
# 50%        0.290000     13.370000     53.640000      5.660000      3.990000
# 75%        1.500000     23.990000     70.810000      9.060000      7.760000
# max      447.030000    126.120000    205.990000    129.700000    104.540000
# std       23.805384     15.824015     30.235222      7.844725      8.264334
#
#                pm10           nh3  ...  precipitation          rain  \
# count  26016.000000  26016.000000  ...   26016.000000  26016.000000
# mean       8.655013      0.885966  ...       0.085178      0.084129
# min        0.530000      0.000000  ...       0.000000      0.000000
# 25%        3.310000      0.290000  ...       0.000000      0.000000
# 50%        5.870000      0.550000  ...       0.000000      0.000000
# 75%       10.420000      1.040000  ...       0.000000      0.000000
# max      108.950000     15.200000  ...      14.700000     14.700000
# std        8.995438      1.104464  ...       0.373882      0.372107
#
#            snowfall  surface_pressure  wind_speed_10m  wind_speed_100m  \
# count  26016.000000       26016.00000    26016.000000     26016.000000
# mean       0.000735        1014.43454       14.641248        24.320783
# min        0.000000         952.70000        0.000000         0.000000
# 25%        0.000000        1007.80000        8.800000        16.500000
# 50%        0.000000        1015.50000       13.200000        23.200000
# 75%        0.000000        1022.10000       19.200000        30.800000
# max        1.400000        1044.70000       68.000000        99.800000
# std        0.018808          11.13624        7.555971        11.249665
#
#        wind_direction           day         month          hour
# count    26016.000000  26016.000000  26016.000000  26016.000000
# mean       190.311308      2.992005      6.530174     11.500192
# min          1.000000      0.000000      1.000000      0.000000
# 25%        102.000000      1.000000      4.000000      5.750000
# 50%        217.000000      3.000000      7.000000     12.000000
# 75%        253.000000      5.000000     10.000000     17.250000
# max        360.000000      6.000000     12.000000     23.000000
# std         93.850252      2.002481      3.436228      6.922264
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Zero values

# %% [markdown]
# There are some pollutant minimum values of 0.000000 which is also very unlikely. This could indicate issues with sensors. Convert any 0.000000 values to NaN.

# %%
weather_aq.iloc[:,:10] = weather_aq.iloc[:,:10].apply(lambda x: x.replace(0, np.nan), axis = 1)
weather_aq.describe()
# Out:
#                            date_time           aqi            co  \
# count                          26016  26016.000000  26016.000000
# mean   2022-07-02 09:23:22.167896576      1.555812    249.608223
# min              2021-01-01 12:00:00      1.000000    141.860000
# 25%              2021-09-30 11:45:00      1.000000    205.280000
# 50%              2022-06-30 11:30:00      1.000000    233.650000
# 75%              2023-04-04 11:15:00      2.000000    270.370000
# max              2024-01-01 12:00:00      5.000000   1268.390000
# std                              NaN      0.744845     80.893333
#
#                  no           no2            o3           so2         pm2_5  \
# count  19189.000000  26016.000000  25064.000000  26016.000000  26016.000000
# mean       8.620351     18.793687     52.987042      7.872474      6.815534
# min        0.010000      1.340000      0.010000      0.860000      0.500000
# 25%        0.150000      7.800000     33.620000      3.810000      2.230000
# 50%        0.720000     13.370000     55.070000      5.660000      3.990000
# 75%        2.680000     23.990000     71.530000      9.060000      7.760000
# max      447.030000    126.120000    205.990000    129.700000    104.540000
# std       27.364630     15.824015     29.088648      7.844725      8.264334
#
#                pm10           nh3  ...  precipitation          rain  \
# count  26016.000000  25879.000000  ...   26016.000000  26016.000000
# mean       8.655013      0.890656  ...       0.085178      0.084129
# min        0.530000      0.010000  ...       0.000000      0.000000
# 25%        3.310000      0.290000  ...       0.000000      0.000000
# 50%        5.870000      0.550000  ...       0.000000      0.000000
# 75%       10.420000      1.040000  ...       0.000000      0.000000
# max      108.950000     15.200000  ...      14.700000     14.700000
# std        8.995438      1.105496  ...       0.373882      0.372107
#
#            snowfall  surface_pressure  wind_speed_10m  wind_speed_100m  \
# count  26016.000000       26016.00000    26016.000000     26016.000000
# mean       0.000735        1014.43454       14.641248        24.320783
# min        0.000000         952.70000        0.000000         0.000000
# 25%        0.000000        1007.80000        8.800000        16.500000
# 50%        0.000000        1015.50000       13.200000        23.200000
# 75%        0.000000        1022.10000       19.200000        30.800000
# max        1.400000        1044.70000       68.000000        99.800000
# std        0.018808          11.13624        7.555971        11.249665
#
#        wind_direction           day         month          hour
# count    26016.000000  26016.000000  26016.000000  26016.000000
# mean       190.311308      2.992005      6.530174     11.500192
# min          1.000000      0.000000      1.000000      0.000000
# 25%        102.000000      1.000000      4.000000      5.750000
# 50%        217.000000      3.000000      7.000000     12.000000
# 75%        253.000000      5.000000     10.000000     17.250000
# max        360.000000      6.000000     12.000000     23.000000
# std         93.850252      2.002481      3.436228      6.922264
#
# [8 rows x 22 columns]

# %%
for column_name in weather_aq.columns:
    print(f"{column_name}: {weather_aq[column_name].isna().sum()}")
# Out:
# date_time: 0
# aqi: 0
# co: 0
# no: 6827
# no2: 0
# o3: 952
# so2: 0
# pm2_5: 0
# pm10: 0
# nh3: 137
# temp_C: 0
# percent_humidity: 0
# precipitation: 0
# rain: 0
# snowfall: 0
# surface_pressure: 0
# wind_speed_10m: 0
# wind_speed_100m: 0
# wind_direction: 0
# day: 0
# month: 0
# hour: 0

# %% [markdown]
# Datasets for nitric oxide (no), ozone(o3) and ammonia(nh3) contain a number of nan values, making this data less reliable/accurate. Will fill these values with the mean average.

# %%
# Replacing missing values with mean

weather_aq['no'] = weather_aq['no'].fillna(weather_aq['no'].mean())
weather_aq['nh3'] = weather_aq['nh3'].fillna(weather_aq['nh3'].mean())
weather_aq['o3'] = weather_aq['o3'].fillna(weather_aq['o3'].mean())

# %%
weather_aq.isna().sum()
# Out:
# date_time           0
# aqi                 0
# co                  0
# no                  0
# no2                 0
# o3                  0
# so2                 0
# pm2_5               0
# pm10                0
# nh3                 0
# temp_C              0
# percent_humidity    0
# precipitation       0
# rain                0
# snowfall            0
# surface_pressure    0
# wind_speed_10m      0
# wind_speed_100m     0
# wind_direction      0
# day                 0
# month               0
# hour                0
# dtype: int64

# %% [markdown]
# ## Save Cleaned data to CSV

# %%
path = '../data_clean/hammersmith_clean.csv'
weather_aq.to_csv(path, index=False)

# %% [markdown]
# <div class="purple extra-padding">
# <h2>Investigating unusually high values</h2>
#
# - There are some very high values in the data.
# - We will focus on the no2, pm2.5 and o3 levels within the data
# - We will also compare data from nearby measuring stations to see if these values are reliable.
# </div>

# %% [markdown]
# #### High values of NO2

# %%
#  Initial visualisation of no2 to spot potential outliers
x = weather_aq.date_time.tolist()
y = weather_aq.no2.tolist()
plt.figure(figsize=(14, 6))
plt.plot(x,y, color='steelblue',label='no2')
plt.show()

# %% [markdown]
# <div class="blue extra-padding">
# Observations:
# <ul>
# <li>Most recordings are below 100 but a few breach this</li>
# <li>Although 100 is more than 2x the WHO recommended limit for no2, it falls within the 'moderate' category of the UK Air Quality Index</li>
# </ul>
# </div>

# %%
count_high_no2 = weather_aq[weather_aq['no2']>=100]
count_high_no2.shape[0]
# Out:
# 28

# %%
count_high_no2 = count_high_no2.iloc[:,:10]
count_high_no2.head(28)
# Out:
#                 date_time  aqi       co      no     no2         o3     so2  \
# 1834  2021-03-19 22:00:00    3   520.71   56.77  100.08  52.987042   23.37
# 1835  2021-03-19 23:00:00    4   554.09   67.06  101.45  52.987042   21.70
# 5933  2021-09-06 17:00:00    4   420.57   32.63  102.82  18.060000   26.70
# 5934  2021-09-06 18:00:00    4   500.68   67.06  120.64   3.040000   40.53
# 5935  2021-09-06 19:00:00    4   560.76   91.20  126.12   0.050000   52.93
# 5936  2021-09-06 20:00:00    4   567.44   98.35  111.04  52.987042   51.98
# 10566 2022-03-20 18:00:00    4   527.38   80.47  102.82   2.010000   54.84
# 10567 2022-03-20 19:00:00    4   594.14  112.65  102.82   0.010000   66.76
# 10662 2022-03-24 18:00:00    4   614.17  119.81  102.82   1.590000   44.35
# 10663 2022-03-24 19:00:00    4   821.11  202.06  117.90   0.010000   58.65
# 10664 2022-03-24 20:00:00    5   921.25  236.03  119.27  52.987042   52.93
# 10665 2022-03-24 21:00:00    5   781.06  168.09  102.82  52.987042   34.81
# 17840 2023-01-22 20:00:00    5  1068.12  282.53  102.82  52.987042   80.11
# 17841 2023-01-22 21:00:00    5  1121.52  296.83  106.93  52.987042   93.46
# 17842 2023-01-22 22:00:00    5  1121.52  293.25  108.30  52.987042  100.14
# 17843 2023-01-22 23:00:00    4  1081.47  271.80  108.30  52.987042   96.32
# 17844 2023-01-23 00:00:00    4   988.01  236.03  105.56  52.987042   82.97
# 17845 2023-01-23 01:00:00    4   894.55  198.48  102.82  52.987042   73.43
# 17846 2023-01-23 02:00:00    3   834.47  173.45  100.08  52.987042   70.57
# 17852 2023-01-23 08:00:00    3   801.09  153.78  104.19  52.987042  103.00
# 17853 2023-01-23 09:00:00    4   881.20  189.54  108.30   0.070000  113.49
# 17854 2023-01-23 10:00:00    4   947.95  214.58  108.30   0.450000  119.21
# 17855 2023-01-23 11:00:00    4   988.01  232.46  106.93   1.080000  118.26
# 17856 2023-01-23 12:00:00    4   988.01  232.46  104.19   1.790000  114.44
# 17857 2023-01-23 13:00:00    4   894.55  198.48  101.45   2.410000   88.69
# 23285 2023-09-08 17:00:00    3   343.80    8.05  105.56  35.760000   14.90
# 23286 2023-09-08 18:00:00    3   383.85   23.25  116.53   3.260000   17.64
# 23287 2023-09-08 19:00:00    3   413.89   41.57  102.82   0.040000   19.79
#
#        pm2_5   pm10    nh3
# 1834   22.09  24.80   1.65
# 1835   25.13  28.00   1.49
# 5933   27.92  31.35   4.88
# 5934   32.64  36.46   6.59
# 5935   36.77  40.83   7.54
# 5936   39.20  43.31   6.65
# 10566  30.77  32.93   9.12
# 10567  35.38  38.09  11.53
# 10662  28.47  35.12   4.94
# 10663  43.77  51.06   6.59
# 10664  53.10  59.72   6.40
# 10665  52.41  57.14   5.32
# 17840  75.67  77.38   6.46
# 17841  80.58  82.13   7.60
# 17842  77.40  78.68   7.92
# 17843  69.46  70.52   7.47
# 17844  59.61  60.49   6.52
# 17845  51.48  52.33   5.70
# 17846  46.04  46.96   5.19
# 17852  43.22  45.34   6.90
# 17853  50.15  52.63   8.61
# 17854  55.63  58.42   9.75
# 17855  58.32  61.20  10.01
# 17856  57.73  60.53   9.25
# 17857  50.47  53.25   5.00
# 23285  36.90  39.08   2.56
# 23286  37.86  40.26   3.10
# 23287  39.18  41.85   3.42

# %% [markdown]
# <div class="blue extra-padding">
# <strong>Observations:</strong>
# <ul>
#     <li>air quality recordings are particularly bad on these dates (between 3 and 5)</li>
#     <li>recommended levels of other pollutants are also high on these dates</li>
# </ul>

# %% [markdown]
# #### Unusual pm2.5 values

# %%
#  Initial visualisation of pm2.5 to spot potential outliers
x = weather_aq.date_time.tolist()
y = weather_aq.pm2_5.tolist()
plt.figure(figsize=(14, 6))
plt.plot(x,y, color='green',label='pm2.5')
plt.show()

# %%
small_values = weather_aq[weather_aq['pm2_5']<=1]

# %%
small_values.shape
# Out:
# (1305, 22)

# %%
small_values.head(50)
# Out:
#               date_time  aqi      co        no    no2     o3   so2  pm2_5  \
# 86  2021-01-05 02:00:00    1  247.00  0.010000   9.08  45.06  5.72   0.97
# 87  2021-01-05 03:00:00    1  250.34  0.020000   9.08  41.13  5.96   0.98
# 241 2021-01-11 13:00:00    1  210.29  0.270000   8.91  75.10  3.87   0.99
# 242 2021-01-11 14:00:00    1  206.95  0.140000   8.23  79.39  3.49   0.87
# 243 2021-01-11 15:00:00    1  205.28  0.050000   7.97  79.39  3.28   0.90
# 244 2021-01-11 16:00:00    1  205.28  0.010000   7.88  78.68  3.07   0.99
# 253 2021-01-12 01:00:00    2  201.94  8.620351   2.79  83.69  1.54   1.00
# 254 2021-01-12 02:00:00    2  200.27  8.620351   2.53  82.97  1.52   0.91
# 255 2021-01-12 03:00:00    2  200.27  8.620351   2.46  80.82  1.58   0.85
# 256 2021-01-12 04:00:00    1  198.60  8.620351   2.53  78.68  1.68   0.72
# 257 2021-01-12 05:00:00    1  198.60  8.620351   3.04  77.96  2.03   0.60
# 258 2021-01-12 06:00:00    1  201.94  8.620351   4.28  75.82  2.53   0.65
# 426 2021-01-19 06:00:00    1  196.93  8.620351   3.38  67.95  1.70   0.94
# 427 2021-01-19 07:00:00    1  198.60  8.620351   4.67  67.95  2.03   0.83
# 428 2021-01-19 08:00:00    1  200.27  8.620351   6.43  65.80  2.33   0.74
# 429 2021-01-19 09:00:00    1  201.94  8.620351   7.20  65.09  2.53   0.69
# 430 2021-01-19 10:00:00    1  201.94  0.020000   7.11  65.09  2.62   0.76
# 431 2021-01-19 11:00:00    1  200.27  0.050000   6.86  64.37  2.74   1.00
# 468 2021-01-21 00:00:00    1  201.94  8.620351   5.31  70.10  1.97   0.99
# 469 2021-01-21 01:00:00    1  201.94  8.620351   4.20  65.80  1.39   0.91
# 470 2021-01-21 02:00:00    1  203.61  8.620351   3.60  66.52  1.10   0.50
# 471 2021-01-21 03:00:00    1  206.95  8.620351   3.68  72.96  1.31   0.50
# 472 2021-01-21 04:00:00    1  205.28  8.620351   2.79  72.24  1.42   0.50
# 473 2021-01-21 05:00:00    1  206.95  8.620351   2.57  67.95  1.45   0.50
# 474 2021-01-21 06:00:00    1  210.29  8.620351   3.64  62.23  2.03   0.50
# 475 2021-01-21 07:00:00    1  216.96  8.620351   6.00  57.22  2.83   0.54
# 476 2021-01-21 08:00:00    1  220.30  0.010000   7.54  54.36  3.04   0.59
# 477 2021-01-21 09:00:00    1  220.30  0.080000   7.80  55.08  3.04   0.63
# 478 2021-01-21 10:00:00    1  216.96  0.430000   6.77  57.94  2.95   0.63
# 479 2021-01-21 11:00:00    1  213.62  0.500000   6.17  58.65  3.04   0.60
# 480 2021-01-21 12:00:00    1  213.62  0.310000   6.08  58.65  3.07   0.58
# 481 2021-01-21 13:00:00    1  211.95  0.150000   6.43  58.65  3.10   0.57
# 482 2021-01-21 14:00:00    1  211.95  0.190000   7.54  57.22  3.64   0.63
# 483 2021-01-21 15:00:00    1  213.62  0.150000   8.74  55.08  4.05   0.75
# 553 2021-01-24 13:00:00    1  220.30  0.170000   9.34  66.52  4.17   0.95
# 620 2021-01-28 08:00:00    1  196.93  0.020000   9.60  38.62  3.34   0.88
# 637 2021-01-29 01:00:00    1  196.93  8.620351   4.97  50.78  1.85   0.79
# 638 2021-01-29 02:00:00    1  198.60  8.620351   3.68  55.08  1.74   0.83
# 863 2021-02-07 11:00:00    1  223.64  0.210000   8.57  78.68  4.59   0.96
# 864 2021-02-07 12:00:00    2  220.30  0.240000   7.54  82.25  4.35   0.81
# 865 2021-02-07 13:00:00    2  220.30  0.260000   7.37  85.12  4.17   0.77
# 866 2021-02-07 14:00:00    2  223.64  0.270000   8.05  84.40  4.41   0.80
# 867 2021-02-07 15:00:00    2  223.64  0.200000   8.74  83.69  4.47   0.79
# 868 2021-02-07 16:00:00    2  223.64  0.090000   9.17  82.25  4.35   0.80
# 869 2021-02-07 17:00:00    2  226.97  0.020000   9.94  82.25  4.35   0.79
# 870 2021-02-07 18:00:00    2  230.31  8.620351  10.71  82.97  4.77   0.81
# 871 2021-02-07 19:00:00    2  233.65  8.620351  10.97  84.40  5.19   0.89
# 872 2021-02-07 20:00:00    2  236.99  8.620351  10.63  84.40  5.42   0.96
# 873 2021-02-07 21:00:00    2  236.99  8.620351   9.85  84.40  5.36   0.92
# 874 2021-02-07 22:00:00    2  240.33  8.620351   9.43  82.25  5.36   0.89
#
#      pm10   nh3  ...  precipitation  rain  snowfall  surface_pressure  \
# 86   1.85  0.35  ...            0.0   0.0      0.00            1018.8
# 87   1.83  0.34  ...            0.0   0.0      0.00            1018.7
# 241  1.90  0.29  ...            0.0   0.0      0.00            1015.7
# 242  1.83  0.28  ...            0.0   0.0      0.00            1014.9
# 243  1.97  0.30  ...            0.0   0.0      0.00            1014.6
# 244  2.13  0.30  ...            0.0   0.0      0.00            1014.2
# 253  1.31  0.10  ...            0.2   0.2      0.00            1009.4
# 254  1.14  0.09  ...            0.3   0.3      0.00            1008.6
# 255  1.04  0.09  ...            0.7   0.7      0.00            1008.1
# 256  0.85  0.09  ...            0.9   0.9      0.00            1007.7
# 257  0.69  0.08  ...            0.4   0.4      0.00            1007.4
# 258  0.74  0.09  ...            0.1   0.1      0.00            1007.4
# 426  1.05  0.11  ...            0.1   0.1      0.00            1004.2
# 427  0.97  0.16  ...            0.0   0.0      0.00            1004.6
# 428  0.90  0.20  ...            0.0   0.0      0.00            1004.8
# 429  0.90  0.23  ...            0.0   0.0      0.00            1005.2
# 430  1.02  0.22  ...            0.0   0.0      0.00            1005.4
# 431  1.38  0.20  ...            0.0   0.0      0.00            1005.0
# 468  1.14  0.06  ...            1.0   1.0      0.00             973.6
# 469  1.06  0.08  ...            0.2   0.2      0.00             976.9
# 470  0.58  0.13  ...            0.2   0.2      0.00             979.5
# 471  0.57  0.15  ...            0.0   0.0      0.00             981.6
# 472  0.59  0.18  ...            0.0   0.0      0.00             983.1
# 473  0.61  0.24  ...            0.0   0.0      0.00             984.2
# 474  0.71  0.25  ...            0.0   0.0      0.00             984.7
# 475  0.88  0.27  ...            0.0   0.0      0.00             985.2
# 476  1.05  0.30  ...            0.0   0.0      0.00             985.5
# 477  1.15  0.31  ...            0.0   0.0      0.00             985.9
# 478  1.12  0.30  ...            0.0   0.0      0.00             986.1
# 479  1.06  0.29  ...            0.0   0.0      0.00             986.3
# 480  1.06  0.29  ...            0.0   0.0      0.00             985.7
# 481  1.03  0.29  ...            0.0   0.0      0.00             985.1
# 482  1.11  0.31  ...            0.0   0.0      0.00             984.8
# 483  1.23  0.28  ...            0.0   0.0      0.00             984.3
# 553  1.14  0.16  ...            0.8   0.4      0.28             993.4
# 620  1.05  0.23  ...            0.0   0.0      0.00             999.4
# 637  0.90  0.11  ...            1.5   1.5      0.00             994.0
# 638  0.95  0.12  ...            0.1   0.1      0.00             994.2
# 863  1.11  0.35  ...            0.4   0.0      0.28            1003.4
# 864  0.95  0.33  ...            0.5   0.0      0.35            1003.3
# 865  0.91  0.32  ...            0.2   0.0      0.14            1002.9
# 866  0.95  0.32  ...            0.2   0.0      0.14            1002.6
# 867  0.95  0.31  ...            0.2   0.0      0.14            1002.3
# 868  0.97  0.33  ...            0.1   0.0      0.07            1002.2
# 869  0.97  0.40  ...            0.1   0.0      0.07            1002.1
# 870  1.00  0.53  ...            0.1   0.0      0.07            1002.1
# 871  1.11  0.66  ...            0.1   0.0      0.07            1002.0
# 872  1.19  0.74  ...            0.0   0.0      0.00            1001.8
# 873  1.16  0.75  ...            0.0   0.0      0.00            1001.9
# 874  1.15  0.78  ...            0.0   0.0      0.00            1002.1
#
#      wind_speed_10m  wind_speed_100m  wind_direction  day  month  hour
# 86             18.5             34.5              21    1      1     2
# 87             18.9             34.5              21    1      1     3
# 241            29.8             43.1             255    0      1    13
# 242            27.0             41.2             251    0      1    14
# 243            26.5             42.4             255    0      1    15
# 244            25.9             43.0             254    0      1    16
# 253            26.4             44.3             246    1      1     1
# 254            26.3             43.5             248    1      1     2
# 255            28.1             46.4             254    1      1     3
# 256            28.1             46.0             261    1      1     4
# 257            25.2             42.1             268    1      1     5
# 258            22.4             38.4             274    1      1     6
# 426            30.5             49.1             240    1      1     6
# 427            28.3             46.2             243    1      1     7
# 428            29.5             47.7             243    1      1     8
# 429            30.4             48.4             246    1      1     9
# 430            28.5             44.2             245    1      1    10
# 431            27.1             42.0             237    1      1    11
# 468            36.1             56.4             240    3      1     0
# 469            41.4             62.7             263    3      1     1
# 470            33.9             52.4             253    3      1     2
# 471            34.5             54.6             247    3      1     3
# 472            29.0             47.6             238    3      1     4
# 473            26.4             44.3             231    3      1     5
# 474            27.6             46.4             230    3      1     6
# 475            28.3             47.3             229    3      1     7
# 476            29.9             49.4             229    3      1     8
# 477            31.5             49.8             231    3      1     9
# 478            30.7             48.0             231    3      1    10
# 479            30.8             45.6             225    3      1    11
# 480            32.1             46.5             235    3      1    12
# 481            29.5             43.1             235    3      1    13
# 482            23.7             34.7             227    3      1    14
# 483            18.2             29.1             219    3      1    15
# 553            15.1             25.5             123    6      1    13
# 620            26.9             44.2             258    3      1     8
# 637            23.7             39.6             253    4      1     1
# 638            26.7             44.2             256    4      1     2
# 863            31.8             45.3              20    6      2    11
# 864            33.5             48.2              19    6      2    12
# 865            30.7             45.4              14    6      2    13
# 866            33.4             49.0              24    6      2    14
# 867            29.0             44.1              14    6      2    15
# 868            30.2             45.5              22    6      2    16
# 869            30.3             45.3              28    6      2    17
# 870            25.4             39.3              27    6      2    18
# 871            26.6             40.5              28    6      2    19
# 872            27.7             42.6              38    6      2    20
# 873            27.9             43.2              36    6      2    21
# 874            26.6             41.9              33    6      2    22
#
# [50 rows x 22 columns]

# %% [markdown]
# **Observations:**
# - Many of these smaller values were from a time period when the uk was in lock down so are not a true representation of what it is like on a usual day
# - According to a report on road traffic (https://assets.publishing.service.gov.uk/media/633310c1d3bf7f567b3e61fb/road-traffic-estimates-in-great-britain-2021.pdf), traffic levels were significantly less than pre-pandemic levels throughout 2021
# - Will look at data from 2022 and 2023 as traffic levels should be more accurate
# - Unforuntunately the limitations of this data source mean that we cannot look at pre-pandemic levels
# - It is clear from this data that reducing road traffic significantly improves air quality

# %%
start_date = '2021-01-01'
end_date = '2021-12-31'

weather_aq_two_years = weather_aq[~weather_aq['date_time'].between(start_date,end_date)]

# %%
small_values = weather_aq_two_years[weather_aq_two_years['pm2_5']<=1]
small_values.head(50)
# Out:
#                date_time  aqi      co        no    no2     o3   so2  pm2_5  \
# 8820 2022-01-05 00:00:00    1  270.37  8.620351   8.14  52.93  3.64   0.84
# 8821 2022-01-05 01:00:00    1  270.37  8.620351   6.51  55.07  3.19   0.74
# 8822 2022-01-05 02:00:00    1  267.03  8.620351   5.57  56.51  3.01   0.69
# 8823 2022-01-05 03:00:00    1  267.03  8.620351   5.14  57.22  2.98   0.66
# 8824 2022-01-05 04:00:00    1  267.03  8.620351   4.97  57.22  3.04   0.66
# 8825 2022-01-05 05:00:00    1  263.69  8.620351   5.14  57.22  3.28   0.69
# 8826 2022-01-05 06:00:00    1  267.03  8.620351   6.08  57.22  3.73   0.78
# 8859 2022-01-06 15:00:00    2  247.00  0.070000  10.45  80.82  4.65   0.83
# 8860 2022-01-06 16:00:00    1  243.66  0.010000   9.00  77.96  3.87   0.87
# 8861 2022-01-06 17:00:00    1  247.00  8.620351   9.00  74.39  3.70   0.91
# 8862 2022-01-06 18:00:00    1  247.00  8.620351   9.00  72.24  3.49   0.94
# 8880 2022-01-07 12:00:00    1  257.02  1.030000   7.45  62.94  3.99   0.88
# 8881 2022-01-07 13:00:00    1  253.68  0.870000   7.20  63.66  3.67   0.75
# 8882 2022-01-07 14:00:00    1  253.68  0.680000   8.74  62.23  4.11   0.75
# 8883 2022-01-07 15:00:00    1  257.02  0.360000  10.88  60.08  4.65   0.79
# 8907 2022-01-08 15:00:00    1  223.64  0.020000   5.65  70.81  1.89   0.96
# 8910 2022-01-08 18:00:00    1  230.31  8.620351   8.48  65.09  2.65   0.85
# 8911 2022-01-08 19:00:00    1  233.65  8.620351   8.05  65.09  2.80   0.77
# 8912 2022-01-08 20:00:00    1  240.33  8.620351   7.54  65.80  2.83   0.78
# 8913 2022-01-08 21:00:00    1  243.66  8.620351   6.68  65.09  2.65   0.80
# 8914 2022-01-08 22:00:00    1  243.66  8.620351   6.34  63.66  2.56   0.82
# 8915 2022-01-08 23:00:00    1  243.66  8.620351   6.00  60.80  2.41   0.74
# 8916 2022-01-09 00:00:00    1  243.66  8.620351   4.80  58.65  2.03   0.63
# 8917 2022-01-09 01:00:00    1  243.66  8.620351   4.37  59.37  2.00   0.62
# 8918 2022-01-09 02:00:00    1  247.00  8.620351   4.67  59.37  2.26   0.65
# 8919 2022-01-09 03:00:00    1  250.34  8.620351   5.18  59.37  2.56   0.70
# 8920 2022-01-09 04:00:00    1  253.68  8.620351   5.74  59.37  2.92   0.77
# 8921 2022-01-09 05:00:00    1  253.68  8.620351   6.43  57.94  3.31   0.88
# 9422 2022-01-31 02:00:00    1  240.33  8.620351   3.64  72.24  2.18   0.99
# 9423 2022-01-31 03:00:00    1  247.00  8.620351   3.38  77.25  2.26   0.79
# 9424 2022-01-31 04:00:00    1  250.34  8.620351   3.21  77.96  2.32   0.63
# 9425 2022-01-31 05:00:00    1  250.34  8.620351   3.04  77.25  2.32   0.54
# 9426 2022-01-31 06:00:00    1  247.00  8.620351   3.30  76.53  2.47   0.54
# 9427 2022-01-31 07:00:00    1  250.34  8.620351   5.40  73.67  3.22   0.66
# 9428 2022-01-31 08:00:00    1  250.34  8.620351   7.54  69.38  3.81   0.78
# 9429 2022-01-31 09:00:00    1  257.02  0.060000   8.23  66.52  4.17   0.79
# 9430 2022-01-31 10:00:00    1  260.35  0.750000   7.28  72.24  4.47   0.75
# 9431 2022-01-31 11:00:00    2  257.02  0.980000   6.51  81.54  4.59   0.67
# 9432 2022-01-31 12:00:00    2  253.68  1.030000   5.83  87.98  4.47   0.57
# 9433 2022-01-31 13:00:00    2  250.34  0.990000   5.57  90.12  4.23   0.53
# 9434 2022-01-31 14:00:00    2  250.34  1.020000   6.25  87.98  4.65   0.57
# 9435 2022-01-31 15:00:00    2  253.68  0.860000   7.37  83.68  5.13   0.62
# 9436 2022-01-31 16:00:00    1  257.02  0.590000  10.20  76.53  6.20   0.74
# 9437 2022-01-31 17:00:00    1  263.69  0.090000  14.39  65.80  7.27   0.93
# 9528 2022-02-04 12:00:00    1  253.68  1.220000  10.54  65.09  4.59   0.82
# 9529 2022-02-04 13:00:00    1  250.34  1.290000   8.31  70.10  3.99   0.64
# 9530 2022-02-04 14:00:00    1  247.00  1.230000   7.80  71.53  3.87   0.65
# 9531 2022-02-04 15:00:00    1  247.00  0.940000   7.45  71.53  3.64   0.61
# 9532 2022-02-04 16:00:00    1  250.34  0.620000   9.60  66.52  4.11   0.67
# 9533 2022-02-04 17:00:00    1  260.35  0.130000  14.74  58.65  5.01   0.87
#
#       pm10   nh3  ...  precipitation  rain  snowfall  surface_pressure  \
# 8820  1.37  0.89  ...            0.0   0.0       0.0            1006.0
# 8821  1.34  0.86  ...            0.0   0.0       0.0            1006.2
# 8822  1.30  0.79  ...            0.0   0.0       0.0            1006.6
# 8823  1.28  0.70  ...            0.0   0.0       0.0            1007.0
# 8824  1.30  0.62  ...            0.0   0.0       0.0            1007.3
# 8825  1.40  0.59  ...            0.0   0.0       0.0            1007.8
# 8826  1.57  0.62  ...            0.0   0.0       0.0            1008.0
# 8859  1.36  0.20  ...            0.1   0.1       0.0            1013.0
# 8860  1.36  0.18  ...            0.2   0.2       0.0            1012.1
# 8861  1.31  0.15  ...            0.3   0.3       0.0            1011.4
# 8862  1.33  0.13  ...            0.2   0.2       0.0            1010.7
# 8880  1.20  0.36  ...            0.0   0.0       0.0            1009.6
# 8881  1.08  0.38  ...            0.0   0.0       0.0            1008.6
# 8882  1.08  0.42  ...            0.0   0.0       0.0            1008.4
# 8883  1.10  0.46  ...            0.0   0.0       0.0            1008.1
# 8907  1.03  0.11  ...            0.4   0.4       0.0             991.1
# 8910  0.93  0.17  ...            0.1   0.1       0.0             991.4
# 8911  0.87  0.23  ...            0.0   0.0       0.0             992.7
# 8912  0.92  0.28  ...            0.0   0.0       0.0             993.3
# 8913  1.01  0.32  ...            0.0   0.0       0.0             994.0
# 8914  1.09  0.33  ...            0.0   0.0       0.0             995.0
# 8915  1.07  0.33  ...            0.0   0.0       0.0             995.6
# 8916  1.01  0.30  ...            0.0   0.0       0.0             996.2
# 8917  1.05  0.30  ...            0.0   0.0       0.0             997.0
# 8918  1.13  0.31  ...            0.0   0.0       0.0             997.6
# 8919  1.23  0.33  ...            0.0   0.0       0.0             998.2
# 8920  1.37  0.33  ...            0.0   0.0       0.0             998.8
# 8921  1.57  0.30  ...            0.0   0.0       0.0             998.9
# 9422  1.22  0.31  ...            0.0   0.0       0.0            1017.6
# 9423  1.17  0.36  ...            0.0   0.0       0.0            1017.8
# 9424  1.11  0.40  ...            0.0   0.0       0.0            1017.6
# 9425  1.04  0.46  ...            0.0   0.0       0.0            1017.8
# 9426  1.03  0.51  ...            0.0   0.0       0.0            1018.1
# 9427  1.13  0.59  ...            0.0   0.0       0.0            1018.7
# 9428  1.21  0.61  ...            0.0   0.0       0.0            1019.6
# 9429  1.19  0.55  ...            0.0   0.0       0.0            1020.4
# 9430  1.15  0.49  ...            0.0   0.0       0.0            1021.9
# 9431  1.13  0.46  ...            0.0   0.0       0.0            1022.6
# 9432  1.08  0.46  ...            0.0   0.0       0.0            1023.2
# 9433  1.01  0.46  ...            0.0   0.0       0.0            1023.5
# 9434  1.03  0.49  ...            0.0   0.0       0.0            1024.3
# 9435  1.08  0.53  ...            0.0   0.0       0.0            1024.5
# 9436  1.24  0.63  ...            0.0   0.0       0.0            1025.3
# 9437  1.49  0.78  ...            0.0   0.0       0.0            1025.7
# 9528  0.99  0.61  ...            0.0   0.0       0.0            1009.4
# 9529  0.86  0.92  ...            0.1   0.1       0.0            1009.9
# 9530  0.93  1.22  ...            0.1   0.1       0.0            1010.4
# 9531  0.95  1.35  ...            0.0   0.0       0.0            1010.8
# 9532  1.05  1.44  ...            0.0   0.0       0.0            1011.4
# 9533  1.31  1.71  ...            0.0   0.0       0.0            1012.6
#
#       wind_speed_10m  wind_speed_100m  wind_direction  day  month  hour
# 8820            19.6             36.1             284    2      1     0
# 8821            19.6             35.9             283    2      1     1
# 8822            20.3             37.3             283    2      1     2
# 8823            20.8             37.6             280    2      1     3
# 8824            21.3             38.3             281    2      1     4
# 8825            20.4             37.3             284    2      1     5
# 8826            19.6             36.4             287    2      1     6
# 8859            23.6             40.5             201    3      1    15
# 8860            24.9             42.9             202    3      1    16
# 8861            24.6             42.3             205    3      1    17
# 8862            26.1             45.4             206    3      1    18
# 8880            28.8             42.0             250    4      1    12
# 8881            19.2             27.4             244    4      1    13
# 8882            22.7             35.3             250    4      1    14
# 8883            23.0             36.9             250    4      1    15
# 8907            20.0             34.5             232    5      1    15
# 8910            17.9             32.6             280    5      1    18
# 8911            24.7             41.3             286    5      1    19
# 8912            27.4             44.7             289    5      1    20
# 8913            24.7             42.4             286    5      1    21
# 8914            23.6             41.2             278    5      1    22
# 8915            20.9             38.0             271    5      1    23
# 8916            19.8             36.1             269    6      1     0
# 8917            21.2             38.3             270    6      1     1
# 8918            19.1             36.0             266    6      1     2
# 8919            17.0             33.1             265    6      1     3
# 8920            13.6             29.2             259    6      1     4
# 8921            10.7             25.8             250    6      1     5
# 9422            28.7             47.6             290    0      1     2
# 9423            27.3             45.4             288    0      1     3
# 9424            27.5             45.6             292    0      1     4
# 9425            29.0             47.7             297    0      1     5
# 9426            31.4             51.6             300    0      1     6
# 9427            33.9             53.9             303    0      1     7
# 9428            33.7             54.3             307    0      1     8
# 9429            31.1             49.4             311    0      1     9
# 9430            26.8             40.7             312    0      1    10
# 9431            28.5             41.3             315    0      1    11
# 9432            28.6             40.6             318    0      1    12
# 9433            28.6             40.6             324    0      1    13
# 9434            26.4             38.2             322    0      1    14
# 9435            22.9             34.6             312    0      1    15
# 9436            17.8             31.6             313    0      1    16
# 9437            12.4             27.4             300    0      1    17
# 9528            21.9             30.9             290    4      2    12
# 9529            24.2             33.7             285    4      2    13
# 9530            28.3             40.3             282    4      2    14
# 9531            24.8             36.0             269    4      2    15
# 9532            23.1             37.5             266    4      2    16
# 9533            20.6             36.7             266    4      2    17
#
# [50 rows x 22 columns]

# %%
small_values.tail(50)
# Out:
#                 date_time  aqi      co        no    no2     o3   so2  pm2_5  \
# 25967 2023-12-30 11:00:00    2  236.99  0.030000   7.54  73.67  2.59   0.82
# 25968 2023-12-30 12:00:00    2  233.65  0.040000   6.25  75.10  2.18   0.64
# 25969 2023-12-30 13:00:00    2  230.31  0.050000   5.44  77.96  1.74   0.50
# 25970 2023-12-30 14:00:00    2  230.31  0.040000   5.36  79.39  1.74   0.50
# 25971 2023-12-30 15:00:00    2  226.97  0.020000   5.27  77.96  1.77   0.52
# 25972 2023-12-30 16:00:00    2  226.97  8.620351   5.23  76.53  1.74   0.57
# 25973 2023-12-30 17:00:00    2  226.97  8.620351   5.36  75.10  1.68   0.61
# 25974 2023-12-30 18:00:00    2  226.97  8.620351   5.40  75.10  1.62   0.59
# 25975 2023-12-30 19:00:00    2  226.97  8.620351   5.23  75.10  1.68   0.59
# 25976 2023-12-30 20:00:00    2  226.97  8.620351   4.84  75.82  1.65   0.66
# 25977 2023-12-30 21:00:00    2  226.97  8.620351   4.33  76.53  1.52   0.68
# 25978 2023-12-30 22:00:00    2  223.64  8.620351   4.11  75.82  1.43   0.67
# 25979 2023-12-30 23:00:00    2  223.64  8.620351   3.73  76.53  1.28   0.66
# 25980 2023-12-31 00:00:00    2  223.64  8.620351   2.96  75.82  1.01   0.73
# 25981 2023-12-31 01:00:00    2  223.64  8.620351   2.74  74.39  0.95   0.71
# 25982 2023-12-31 02:00:00    2  220.30  8.620351   2.72  73.67  0.95   0.57
# 25983 2023-12-31 03:00:00    2  223.64  8.620351   2.66  75.10  1.01   0.51
# 25984 2023-12-31 04:00:00    2  223.64  8.620351   2.66  77.25  1.13   0.52
# 25985 2023-12-31 05:00:00    2  226.97  8.620351   3.43  79.39  1.51   0.66
# 25986 2023-12-31 06:00:00    2  226.97  8.620351   4.16  80.82  1.76   0.74
# 25987 2023-12-31 07:00:00    2  230.31  8.620351   5.06  80.82  2.03   0.57
# 25988 2023-12-31 08:00:00    2  233.65  8.620351   6.43  75.82  2.35   0.50
# 25989 2023-12-31 09:00:00    2  240.33  0.010000   6.85  72.24  2.47   0.50
# 25990 2023-12-31 10:00:00    2  236.99  0.110000   6.00  67.95  2.29   0.52
# 25991 2023-12-31 11:00:00    2  230.31  0.150000   4.93  73.67  2.09   0.50
# 25992 2023-12-31 12:00:00    2  230.31  0.100000   4.33  70.10  1.88   0.50
# 25993 2023-12-31 13:00:00    2  236.99  0.090000   3.68  68.66  1.48   0.50
# 25994 2023-12-31 14:00:00    2  233.65  0.150000   3.77  67.95  1.45   0.50
# 25995 2023-12-31 15:00:00    2  233.65  0.130000   3.98  65.80  1.48   0.50
# 25996 2023-12-31 16:00:00    2  230.31  0.020000   4.28  62.23  1.46   0.50
# 25997 2023-12-31 17:00:00    2  230.31  8.620351   4.63  65.80  1.40   0.50
# 25998 2023-12-31 18:00:00    2  226.97  8.620351   4.93  71.53  1.42   0.50
# 25999 2023-12-31 19:00:00    2  230.31  8.620351   5.01  69.38  1.55   0.50
# 26000 2023-12-31 20:00:00    2  230.31  8.620351   4.63  67.95  1.53   0.50
# 26001 2023-12-31 21:00:00    2  230.31  8.620351   3.86  69.38  1.42   0.50
# 26002 2023-12-31 22:00:00    2  230.31  8.620351   3.43  69.38  1.34   0.50
# 26003 2023-12-31 23:00:00    2  230.31  8.620351   3.00  68.66  1.19   0.50
# 26004 2024-01-01 00:00:00    2  230.31  8.620351   2.21  67.95  0.94   0.50
# 26005 2024-01-01 01:00:00    2  230.31  8.620351   2.21  67.23  1.16   0.50
# 26006 2024-01-01 02:00:00    2  230.31  8.620351   2.16  67.23  1.28   0.50
# 26007 2024-01-01 03:00:00    2  233.65  8.620351   2.25  67.23  1.42   0.50
# 26008 2024-01-01 04:00:00    2  233.65  8.620351   2.46  67.23  1.61   0.50
# 26009 2024-01-01 05:00:00    2  233.65  8.620351   2.78  66.52  1.86   0.50
# 26010 2024-01-01 06:00:00    2  233.65  8.620351   3.47  67.23  2.21   0.50
# 26011 2024-01-01 07:00:00    2  240.33  8.620351   6.17  65.80  3.13   0.55
# 26012 2024-01-01 08:00:00    2  240.33  8.620351   9.42  63.66  3.87   0.72
# 26013 2024-01-01 09:00:00    2  240.33  0.010000  10.88  64.37  4.29   0.81
# 26014 2024-01-01 10:00:00    2  236.99  0.080000  10.37  70.10  4.29   0.80
# 26015 2024-01-01 11:00:00    2  236.99  0.210000   9.08  75.10  3.99   0.68
# 26016 2024-01-01 12:00:00    2  233.65  0.300000   7.97  77.96  3.61   0.57
#
#        pm10   nh3  ...  precipitation  rain  snowfall  surface_pressure  \
# 25967  1.21  0.17  ...            0.2   0.2       0.0            1005.7
# 25968  1.02  0.17  ...            0.1   0.1       0.0            1004.4
# 25969  0.82  0.16  ...            0.1   0.1       0.0            1003.6
# 25970  0.87  0.17  ...            0.1   0.1       0.0            1002.4
# 25971  0.97  0.19  ...            0.0   0.0       0.0            1001.5
# 25972  1.09  0.21  ...            0.0   0.0       0.0            1000.7
# 25973  1.17  0.22  ...            0.0   0.0       0.0             999.5
# 25974  1.13  0.22  ...            0.0   0.0       0.0             998.2
# 25975  1.11  0.22  ...            0.0   0.0       0.0             997.1
# 25976  1.24  0.23  ...            0.1   0.1       0.0             996.1
# 25977  1.29  0.21  ...            0.1   0.1       0.0             994.8
# 25978  1.15  0.18  ...            0.1   0.1       0.0             993.4
# 25979  0.98  0.13  ...            0.6   0.6       0.0             991.6
# 25980  0.99  0.10  ...            1.3   1.3       0.0             989.7
# 25981  0.91  0.08  ...            2.1   2.1       0.0             988.4
# 25982  0.68  0.05  ...            1.6   1.6       0.0             987.7
# 25983  0.59  0.05  ...            1.2   1.2       0.0             986.8
# 25984  0.63  0.05  ...            0.4   0.4       0.0             985.4
# 25985  0.90  0.05  ...            0.6   0.6       0.0             984.6
# 25986  1.03  0.06  ...            0.3   0.3       0.0             985.2
# 25987  0.80  0.11  ...            0.0   0.0       0.0             986.2
# 25988  0.76  0.16  ...            0.0   0.0       0.0             986.4
# 25989  0.86  0.15  ...            0.0   0.0       0.0             986.4
# 25990  0.93  0.13  ...            0.0   0.0       0.0             986.4
# 25991  0.88  0.13  ...            0.0   0.0       0.0             985.9
# 25992  0.80  0.14  ...            0.0   0.0       0.0             985.8
# 25993  0.69  0.15  ...            0.0   0.0       0.0             986.4
# 25994  0.67  0.19  ...            0.0   0.0       0.0             986.4
# 25995  0.68  0.22  ...            0.0   0.0       0.0             986.9
# 25996  0.70  0.25  ...            0.0   0.0       0.0             987.6
# 25997  0.73  0.30  ...            0.0   0.0       0.0             988.1
# 25998  0.77  0.34  ...            0.0   0.0       0.0             988.7
# 25999  0.80  0.36  ...            0.1   0.1       0.0             989.5
# 26000  0.80  0.34  ...            0.0   0.0       0.0             990.4
# 26001  0.78  0.30  ...            0.0   0.0       0.0             991.1
# 26002  0.75  0.26  ...            0.0   0.0       0.0             992.0
# 26003  0.71  0.23  ...            0.0   0.0       0.0             992.9
# 26004  0.71  0.20  ...            0.0   0.0       0.0             993.8
# 26005  0.78  0.21  ...            0.0   0.0       0.0             994.9
# 26006  0.81  0.20  ...            0.0   0.0       0.0             995.8
# 26007  0.83  0.20  ...            0.0   0.0       0.0             996.8
# 26008  0.86  0.21  ...            0.0   0.0       0.0             997.8
# 26009  0.90  0.24  ...            0.0   0.0       0.0             998.5
# 26010  0.93  0.29  ...            0.0   0.0       0.0             999.4
# 26011  1.07  0.40  ...            0.0   0.0       0.0            1000.5
# 26012  1.39  0.52  ...            0.0   0.0       0.0            1001.5
# 26013  1.65  0.62  ...            0.0   0.0       0.0            1002.3
# 26014  1.69  0.67  ...            0.0   0.0       0.0            1002.7
# 26015  1.44  0.67  ...            0.0   0.0       0.0            1003.2
# 26016  1.13  0.63  ...            0.0   0.0       0.0            1003.1
#
#        wind_speed_10m  wind_speed_100m  wind_direction  day  month  hour
# 25967            30.6             48.2             200    5     12    11
# 25968            31.1             47.5             200    5     12    12
# 25969            28.2             43.4             203    5     12    13
# 25970            27.8             42.9             201    5     12    14
# 25971            28.6             45.0             197    5     12    15
# 25972            29.9             47.6             193    5     12    16
# 25973            31.8             49.7             190    5     12    17
# 25974            33.0             52.5             187    5     12    18
# 25975            34.0             53.4             185    5     12    19
# 25976            34.4             53.9             187    5     12    20
# 25977            35.8             56.2             186    5     12    21
# 25978            37.0             57.4             187    5     12    22
# 25979            33.8             53.0             181    5     12    23
# 25980            40.7             63.0             178    6     12     0
# 25981            32.7             49.3             201    6     12     1
# 25982            25.1             39.9             205    6     12     2
# 25983            20.4             33.8             197    6     12     3
# 25984            31.4             49.8             193    6     12     4
# 25985            28.1             44.9             203    6     12     5
# 25986            28.2             44.2             231    6     12     6
# 25987            21.7             36.2             227    6     12     7
# 25988            22.2             38.8             212    6     12     8
# 25989            26.2             43.4             207    6     12     9
# 25990            29.8             46.1             207    6     12    10
# 25991            31.1             46.5             215    6     12    11
# 25992            29.5             43.2             219    6     12    12
# 25993            29.5             44.6             225    6     12    13
# 25994            29.1             44.3             230    6     12    14
# 25995            27.4             43.6             235    6     12    15
# 25996            25.4             42.1             232    6     12    16
# 25997            26.9             43.8             231    6     12    17
# 25998            29.9             47.2             234    6     12    18
# 25999            32.2             50.1             238    6     12    19
# 26000            32.1             50.4             241    6     12    20
# 26001            31.0             48.0             239    6     12    21
# 26002            31.1             49.1             242    6     12    22
# 26003            30.6             48.2             243    6     12    23
# 26004            29.5             47.4             246    0      1     0
# 26005            29.0             47.0             245    0      1     1
# 26006            26.8             44.1             248    0      1     2
# 26007            26.0             42.7             251    0      1     3
# 26008            26.2             43.3             252    0      1     4
# 26009            26.0             43.3             256    0      1     5
# 26010            24.9             41.8             256    0      1     6
# 26011            22.9             39.4             257    0      1     7
# 26012            19.6             35.5             256    0      1     8
# 26013            19.3             34.1             256    0      1     9
# 26014            19.1             31.7             248    0      1    10
# 26015            18.2             29.4             236    0      1    11
# 26016            16.6             25.6             228    0      1    12
#
# [50 rows x 22 columns]

# %%
small_values.shape
# Out:
# (845, 22)

# %%
large_values = weather_aq_two_years[weather_aq_two_years['pm2_5']>=70]
large_values.shape
# Out:
# (25, 22)

# %%
large_values
# Out:
#                 date_time  aqi       co      no     no2         o3     so2  \
# 9046  2022-01-14 10:00:00    5  1041.41  271.80   75.40   1.030000   56.27
# 9047  2022-01-14 11:00:00    5  1081.47  286.10   76.77   2.100000   40.05
# 9048  2022-01-14 12:00:00    5  1081.47  286.10   78.14   2.860000   35.76
# 9052  2022-01-14 16:00:00    5   841.14  189.54   85.00   0.580000   46.73
# 9053  2022-01-14 17:00:00    5   854.49  214.58   82.25  52.987042   54.84
# 9054  2022-01-14 18:00:00    5   881.20  243.19   82.25  52.987042   70.57
# 9055  2022-01-14 19:00:00    5   921.25  261.07   80.88  52.987042   79.15
# 10675 2022-03-25 07:00:00    5   433.92    9.95   67.17   4.780000   15.26
# 10676 2022-03-25 08:00:00    5   494.00   36.21   66.49  11.350000   22.17
# 10677 2022-03-25 09:00:00    5   540.73   56.77   66.49  17.170000   28.13
# 10678 2022-03-25 10:00:00    5   467.30   32.63   61.69  39.340000   33.86
# 10679 2022-03-25 11:00:00    5   423.91   24.59   47.30  46.490000   30.99
# 17840 2023-01-22 20:00:00    5  1068.12  282.53  102.82  52.987042   80.11
# 17841 2023-01-22 21:00:00    5  1121.52  296.83  106.93  52.987042   93.46
# 17842 2023-01-22 22:00:00    5  1121.52  293.25  108.30  52.987042  100.14
# 17891 2023-01-24 23:00:00    4  1081.47  286.10   77.46  52.987042   74.39
# 17892 2023-01-25 00:00:00    5  1081.47  282.53   78.83  52.987042   70.57
# 17893 2023-01-25 01:00:00    4  1054.76  275.37   80.20  52.987042   65.80
# 17894 2023-01-25 02:00:00    4  1014.71  257.49   80.88  52.987042   61.99
# 18224 2023-02-07 20:00:00    4   988.01  293.25   87.74  52.987042  129.70
# 18225 2023-02-07 21:00:00    4   988.01  286.10   82.25  52.987042  115.39
# 18401 2023-02-15 05:00:00    4   494.00    0.12   30.50  21.280000    5.30
# 18402 2023-02-15 06:00:00    4   520.71    0.33   34.96  15.560000    5.60
# 23300 2023-09-09 08:00:00    4   460.62  102.82   55.52   3.580000   46.25
# 23301 2023-09-09 09:00:00    4   494.00  118.02   61.01   6.880000   47.68
#
#         pm2_5    pm10    nh3  ...  precipitation  rain  snowfall  \
# 9046    71.93   76.07   4.02  ...            0.0   0.0       0.0
# 9047    78.46   82.78   1.93  ...            0.0   0.0       0.0
# 9048    82.39   86.78   1.20  ...            0.0   0.0       0.0
# 9052    70.40   74.62   1.25  ...            0.0   0.0       0.0
# 9053    71.05   75.43   2.79  ...            0.0   0.0       0.0
# 9054    72.04   76.31   4.88  ...            0.0   0.0       0.0
# 9055    72.51   76.14   6.27  ...            0.0   0.0       0.0
# 10675   72.17   75.89   0.46  ...            0.0   0.0       0.0
# 10676   91.18   95.21   0.75  ...            0.0   0.0       0.0
# 10677  104.54  108.95   1.20  ...            0.0   0.0       0.0
# 10678   92.31   97.15   1.47  ...            0.0   0.0       0.0
# 10679   77.39   82.32   2.15  ...            0.0   0.0       0.0
# 17840   75.67   77.38   6.46  ...            0.0   0.0       0.0
# 17841   80.58   82.13   7.60  ...            0.0   0.0       0.0
# 17842   77.40   78.68   7.92  ...            0.0   0.0       0.0
# 17891   74.11   77.01   8.11  ...            0.0   0.0       0.0
# 17892   75.19   77.57   7.79  ...            0.0   0.0       0.0
# 17893   73.99   75.85   7.22  ...            0.0   0.0       0.0
# 17894   70.24   71.90   6.65  ...            0.0   0.0       0.0
# 18224   74.64   81.24  10.64  ...            0.0   0.0       0.0
# 18225   74.21   80.63  10.13  ...            0.0   0.0       0.0
# 18401   72.26   74.99   0.33  ...            0.0   0.0       0.0
# 18402   74.16   76.90   0.44  ...            0.0   0.0       0.0
# 23300   73.03   76.26   4.12  ...            0.0   0.0       0.0
# 23301   73.36   76.76   4.56  ...            0.0   0.0       0.0
#
#        surface_pressure  wind_speed_10m  wind_speed_100m  wind_direction  day  \
# 9046             1036.4             4.1              8.9              52    4
# 9047             1035.9             0.8              1.1             243    4
# 9048             1035.2             2.3              4.8              39    4
# 9052             1033.6             5.5              9.8              67    4
# 9053             1033.5             7.0              7.2              69    4
# 9054             1033.4             6.6             10.8              49    4
# 9055             1033.0             7.0             14.5              55    4
# 10675            1030.4             9.6             17.4              56    4
# 10676            1030.6             7.1             16.8              49    4
# 10677            1031.1             8.2             12.6              52    4
# 10678            1031.4            10.8             14.3              60    4
# 10679            1031.2            13.4             17.2              70    4
# 17840            1035.2             3.0              4.7              14    6
# 17841            1035.6             1.9              2.3              22    6
# 17842            1035.8             2.9              3.0              60    6
# 17891            1037.1             2.3              2.6              18    1
# 17892            1036.8             2.0              1.4             225    2
# 17893            1036.3             2.5              1.3             270    2
# 17894            1036.1             4.0              5.0             275    2
# 18224            1037.6            10.6             13.5             114    1
# 18225            1037.6            10.5             14.3             131    1
# 18401            1022.9            13.1             21.1             201    2
# 18402            1022.8            12.7             20.2             209    2
# 23300            1014.9             1.5              4.6             256    5
# 23301            1014.8             0.4              0.7              90    5
#
#        month  hour
# 9046       1    10
# 9047       1    11
# 9048       1    12
# 9052       1    16
# 9053       1    17
# 9054       1    18
# 9055       1    19
# 10675      3     7
# 10676      3     8
# 10677      3     9
# 10678      3    10
# 10679      3    11
# 17840      1    20
# 17841      1    21
# 17842      1    22
# 17891      1    23
# 17892      1     0
# 17893      1     1
# 17894      1     2
# 18224      2    20
# 18225      2    21
# 18401      2     5
# 18402      2     6
# 23300      9     8
# 23301      9     9
#
# [25 rows x 22 columns]

# %% [markdown]
# **Observations:**
# - Some of these readings are above usual levels but generally occur within rush hour
# - No significant events (e.g. fires) happened on these dates in the local area

# %%
large_and_small = pd.concat([small_values, large_values])

# %%
large_and_small.shape
# Out:
# (870, 22)

# %%
correlation_matrix = large_and_small.iloc[:,1:-3].corr()
correlation_matrix
# Out:
#                        aqi        co        no       no2        o3       so2  \
# aqi               1.000000  0.634757  0.601844  0.635435  0.022021  0.584397
# co                0.634757  1.000000  0.960406  0.930764 -0.352877  0.913963
# no                0.601844  0.960406  1.000000  0.893830 -0.322923  0.929154
# no2               0.635435  0.930764  0.893830  1.000000 -0.484958  0.920667
# o3                0.022021 -0.352877 -0.322923 -0.484958  1.000000 -0.311186
# so2               0.584397  0.913963  0.929154  0.920667 -0.311186  1.000000
# pm2_5             0.710268  0.878254  0.817780  0.931359 -0.463277  0.835314
# pm10              0.712111  0.877178  0.817313  0.929159 -0.458783  0.836041
# nh3               0.402496  0.777253  0.790105  0.742533 -0.151482  0.870084
# temp_C           -0.120782 -0.402254 -0.338925 -0.272484  0.083761 -0.277067
# percent_humidity  0.102223  0.180182  0.235928  0.198795 -0.372179  0.152721
# precipitation     0.003092 -0.059677 -0.047354 -0.058066  0.009715 -0.062269
# rain              0.004405 -0.060296 -0.047061 -0.057797  0.009735 -0.062407
# snowfall         -0.017584  0.003699 -0.007710 -0.008240  0.000498 -0.003029
# surface_pressure  0.172614  0.367877  0.325733  0.381899 -0.055706  0.379335
# wind_speed_10m   -0.181113 -0.316653 -0.344102 -0.444142  0.448514 -0.366083
# wind_speed_100m  -0.225753 -0.346808 -0.352515 -0.474295  0.374361 -0.408616
# wind_direction   -0.389340 -0.313309 -0.285517 -0.326210 -0.034101 -0.304642
#
#                      pm2_5      pm10       nh3    temp_C  percent_humidity  \
# aqi               0.710268  0.712111  0.402496 -0.120782          0.102223
# co                0.878254  0.877178  0.777253 -0.402254          0.180182
# no                0.817780  0.817313  0.790105 -0.338925          0.235928
# no2               0.931359  0.929159  0.742533 -0.272484          0.198795
# o3               -0.463277 -0.458783 -0.151482  0.083761         -0.372179
# so2               0.835314  0.836041  0.870084 -0.277067          0.152721
# pm2_5             1.000000  0.999512  0.662573 -0.227132          0.147278
# pm10              0.999512  1.000000  0.664035 -0.230967          0.143808
# nh3               0.662573  0.664035  1.000000 -0.246421         -0.118403
# temp_C           -0.227132 -0.230967 -0.246421  1.000000         -0.347173
# percent_humidity  0.147278  0.143808 -0.118403 -0.347173          1.000000
# precipitation    -0.058973 -0.064916 -0.140142  0.065123          0.213402
# rain             -0.058565 -0.064474 -0.140621  0.070565          0.216636
# snowfall         -0.010195 -0.011119 -0.004562 -0.068764         -0.027074
# surface_pressure  0.376789  0.380874  0.450638 -0.051002         -0.332708
# wind_speed_10m   -0.371512 -0.368628 -0.276207 -0.061935         -0.204751
# wind_speed_100m  -0.403819 -0.400018 -0.341626 -0.200987         -0.006393
# wind_direction   -0.334788 -0.335654 -0.124552  0.189538         -0.178235
#
#                   precipitation      rain  snowfall  surface_pressure  \
# aqi                    0.003092  0.004405 -0.017584          0.172614
# co                    -0.059677 -0.060296  0.003699          0.367877
# no                    -0.047354 -0.047061 -0.007710          0.325733
# no2                   -0.058066 -0.057797 -0.008240          0.381899
# o3                     0.009715  0.009735  0.000498         -0.055706
# so2                   -0.062269 -0.062407 -0.003029          0.379335
# pm2_5                 -0.058973 -0.058565 -0.010195          0.376789
# pm10                  -0.064916 -0.064474 -0.011119          0.380874
# nh3                   -0.140142 -0.140621 -0.004562          0.450638
# temp_C                 0.065123  0.070565 -0.068764         -0.051002
# percent_humidity       0.213402  0.216636 -0.027074         -0.332708
# precipitation          1.000000  0.997321  0.115303         -0.241273
# rain                   0.997321  1.000000  0.042333         -0.245107
# snowfall               0.115303  0.042333  1.000000          0.033018
# surface_pressure      -0.241273 -0.245107  0.033018          1.000000
# wind_speed_10m         0.098091  0.100263 -0.021750         -0.249342
# wind_speed_100m        0.103596  0.105628 -0.019422         -0.323911
# wind_direction        -0.155904 -0.154029 -0.037770         -0.015652
#
#                   wind_speed_10m  wind_speed_100m  wind_direction
# aqi                    -0.181113        -0.225753       -0.389340
# co                     -0.316653        -0.346808       -0.313309
# no                     -0.344102        -0.352515       -0.285517
# no2                    -0.444142        -0.474295       -0.326210
# o3                      0.448514         0.374361       -0.034101
# so2                    -0.366083        -0.408616       -0.304642
# pm2_5                  -0.371512        -0.403819       -0.334788
# pm10                   -0.368628        -0.400018       -0.335654
# nh3                    -0.276207        -0.341626       -0.124552
# temp_C                 -0.061935        -0.200987        0.189538
# percent_humidity       -0.204751        -0.006393       -0.178235
# precipitation           0.098091         0.103596       -0.155904
# rain                    0.100263         0.105628       -0.154029
# snowfall               -0.021750        -0.019422       -0.037770
# surface_pressure       -0.249342        -0.323911       -0.015652
# wind_speed_10m          1.000000         0.945143        0.055005
# wind_speed_100m         0.945143         1.000000        0.067558
# wind_direction          0.055005         0.067558        1.000000

# %%
plt.figure(figsize = (15,15))
sns.heatmap(data = correlation_matrix, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# - The heatmap shows a correlation in this data between pm2.5 and other pollutants which should mean that there were not innacuracies in meter readings.
# - There is a negative correlation between particulate matter and wind speed
# - Large values are under-rpresented in this data so heatmap may not be completely accurate. But correlation is similar to that within heatmap of entire dataset below.
# - Therefore, high values may be down to high traffic

# %% [markdown]
# <div class="green extra-padding">
#     <h2>Compare to data from nearby monitoring station (Hammersmith town centre)</h2>
#     <p>
#        This data has been cleaned in another file.
#     </p>
# </div>

# %%
hammersmith_verified = pd.read_csv('../data_clean/hammersmith_verified_clean.csv')

# %%
weather_aq['date_time'] = pd.to_datetime(weather_aq['date_time'])
hammersmith_verified['date_time'] = pd.to_datetime(hammersmith_verified['date_time'])

# Merge the DataFrames
combined_df = pd.merge(weather_aq, hammersmith_verified, on='date_time')

combined_df
# Out:
#                 date_time  aqi      co         no    no2     o3    so2  pm2_5  \
# 0     2021-01-01 12:00:00    2  320.44  13.190000  46.61   2.33  28.61  16.74
# 1     2021-01-01 13:00:00    2  323.77  15.650000  43.87   2.12  24.08  16.56
# 2     2021-01-01 14:00:00    2  323.77  17.430000  43.18   1.43  21.22  15.27
# 3     2021-01-01 15:00:00    2  327.11  18.330000  44.55   0.65  19.31  13.24
# 4     2021-01-01 16:00:00    2  330.45  17.430000  45.93   0.10  17.41  10.69
# ...                   ...  ...     ...        ...    ...    ...    ...    ...
# 25132 2023-12-31 18:00:00    2  226.97   8.620351   4.93  71.53   1.42   0.50
# 25133 2023-12-31 19:00:00    2  230.31   8.620351   5.01  69.38   1.55   0.50
# 25134 2023-12-31 20:00:00    2  230.31   8.620351   4.63  67.95   1.53   0.50
# 25135 2023-12-31 22:00:00    2  230.31   8.620351   3.43  69.38   1.34   0.50
# 25136 2023-12-31 23:00:00    2  230.31   8.620351   3.00  68.66   1.19   0.50
#
#         pm10   nh3  ...  wind_direction  day  month  hour  PM10        NO  \
# 0      17.83  1.98  ...             265    4      1    12  26.7  11.66003
# 1      17.74  1.44  ...             270    4      1    13  30.8  27.47158
# 2      16.50  1.24  ...             263    4      1    14  28.3  25.77877
# 3      14.59  1.03  ...             252    4      1    15  30.8  55.07201
# 4      12.15  0.82  ...             267    4      1    16  31.7  60.04309
# ...      ...   ...  ...             ...  ...    ...   ...   ...       ...
# 25132   0.77  0.34  ...             234    6     12    18   1.7   2.46913
# 25133   0.80  0.36  ...             238    6     12    19   2.5   3.42369
# 25134   0.80  0.34  ...             241    6     12    20   6.7   2.02518
# 25135   0.75  0.26  ...             242    6     12    22   5.0   2.05812
# 25136   0.71  0.23  ...             243    6     12    23   4.2   1.78062
#
#             NO2   NOXasNO2        O3  PM25
# 0      29.97269   47.85115  11.99416  30.4
# 1      40.10981   82.23232   4.53523  34.4
# 2      37.57243   77.09933   4.13110  32.4
# 3      45.89371  130.33628   2.42977  35.4
# 4      50.81270  142.87749   1.45187  32.4
# ...         ...        ...       ...   ...
# 25132  10.18426   13.97021  64.34237   2.0
# 25133   8.45878   13.70836  64.22143   5.0
# 25134   8.77049   11.87572  66.02280   4.0
# 25135   6.04593    9.20166  65.99456   2.0
# 25136   5.62552    8.35576  67.81094   2.0
#
# [25137 rows x 28 columns]

# %%
combined_df.columns
# Out:
# Index(['date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'temp_C', 'percent_humidity', 'precipitation', 'rain',
#        'snowfall', 'surface_pressure', 'wind_speed_10m', 'wind_speed_100m',
#        'wind_direction', 'day', 'month', 'hour', 'PM10', 'NO', 'NO2',
#        'NOXasNO2', 'O3', 'PM25'],
#       dtype='object')

# %%
# Drop columns to make is easier to compare no2 and pm readings
combined_df = combined_df.drop(columns=['co','no','o3','so2','nh3', 'NO','O3'])
columns_to_view = ['date_time','aqi','no2','pm2_5','PM10', 'NO2', 'PM25']
selected_columns = combined_df[columns_to_view]
selected_columns
# Out:
#                 date_time  aqi    no2  pm2_5  PM10       NO2  PM25
# 0     2021-01-01 12:00:00    2  46.61  16.74  26.7  29.97269  30.4
# 1     2021-01-01 13:00:00    2  43.87  16.56  30.8  40.10981  34.4
# 2     2021-01-01 14:00:00    2  43.18  15.27  28.3  37.57243  32.4
# 3     2021-01-01 15:00:00    2  44.55  13.24  30.8  45.89371  35.4
# 4     2021-01-01 16:00:00    2  45.93  10.69  31.7  50.81270  32.4
# ...                   ...  ...    ...    ...   ...       ...   ...
# 25132 2023-12-31 18:00:00    2   4.93   0.50   1.7  10.18426   2.0
# 25133 2023-12-31 19:00:00    2   5.01   0.50   2.5   8.45878   5.0
# 25134 2023-12-31 20:00:00    2   4.63   0.50   6.7   8.77049   4.0
# 25135 2023-12-31 22:00:00    2   3.43   0.50   5.0   6.04593   2.0
# 25136 2023-12-31 23:00:00    2   3.00   0.50   4.2   5.62552   2.0
#
# [25137 rows x 7 columns]

# %%
selected_columns.describe()
# Out:
#                            date_time           aqi           no2  \
# count                          25137  25137.000000  25137.000000
# mean   2022-06-26 08:14:56.097386752      1.561045     19.088840
# min              2021-01-01 12:00:00      1.000000      1.340000
# 25%              2021-09-23 00:00:00      1.000000      7.970000
# 50%              2022-06-25 11:00:00      1.000000     13.710000
# 75%              2023-03-28 09:00:00      2.000000     24.680000
# max              2023-12-31 23:00:00      5.000000    126.120000
# std                              NaN      0.749830     15.931337
#
#               pm2_5          PM10           NO2          PM25
# count  25137.000000  25137.000000  25137.000000  25137.000000
# mean       6.951703     19.576449     44.930537      9.647751
# min        0.500000      0.800000      0.510530      0.250000
# 25%        2.300000     11.700000     23.005960      5.000000
# 50%        4.100000     15.800000     41.131840      7.000000
# 75%        7.970000     23.300000     62.112200     12.000000
# max      104.540000    243.300000    300.888520    179.000000
# std        8.331071     13.210825     27.476539      8.498177

# %%
high_no2 = combined_df[(combined_df['no2']>150)|(combined_df['NO2']>150)]
high_no2.shape
# Out:
# (956, 21)

# %% [markdown]
# <div class="blue extra-padding">
#     <strong>Observations:</strong>
#     <ul>
#         <li>The combined data shows differences in measurements on most days</li>
#         <li>On most other days it is more in line, and often lower than the second set of data</li>
#         <li>API data is caputured from satelites so may be causing inaccuracies</li>
#         <li>Could be slight differences in locations of measuring station, i.e. the second set is from the town centre</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="green">
#     <br>
#     <h2 class="center">Data Visualisation</h2>
#     <br>
# </div>

# %% [markdown]
# <div class="purple extra-padding">
#     <h3>Visualising NO2 data by day</h3>
# </div>

# %%
# Merge DataFrames for both sets of data so that they can be visualised side by side
weather_aq = pd.merge(weather_aq, hammersmith_verified, on="date_time")

# %%
weather_aq.columns
# Out:
# Index(['date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'temp_C', 'percent_humidity', 'precipitation', 'rain',
#        'snowfall', 'surface_pressure', 'wind_speed_10m', 'wind_speed_100m',
#        'wind_direction', 'day', 'month', 'hour', 'PM10', 'NO', 'NO2',
#        'NOXasNO2', 'O3', 'PM25'],
#       dtype='object')

# %%
weather_aq['date_time'] = pd.to_datetime(weather_aq['date_time'])

# Use a temporary DataFrame for resampling by day
temp_df = weather_aq.set_index('date_time')
daily_data = temp_df.resample('D').mean().reset_index()

daily_data.head()
# Out:
#    date_time       aqi          co         no        no2         o3  \
# 0 2021-01-01  1.916667  314.315000  11.092500  45.410833   1.699167
# 1 2021-01-02  1.333333  289.977083   7.822917  34.516250  13.347500
# 2 2021-01-03  1.125000  294.845833   3.508333  30.002500   9.265000
# 3 2021-01-04  1.000000  276.764167   0.270417  16.545417  30.358333
# 4 2021-01-05  1.000000  260.353333   0.202500  16.657500  33.126250
#
#          so2     pm2_5       pm10       nh3  ...  wind_direction  day  month  \
# 0  17.872500  9.675833  10.928333  0.888333  ...      300.666667  4.0    1.0
# 1  13.712083  6.353333   7.679167  0.727083  ...      321.708333  5.0    1.0
# 2  12.012917  5.781667   6.535000  0.675833  ...       40.125000  6.0    1.0
# 3   7.579583  2.278333   3.378333  0.352917  ...       30.375000  0.0    1.0
# 4   8.225000  1.749167   2.325000  0.352500  ...       20.625000  1.0    1.0
#
#    hour       PM10         NO        NO2    NOXasNO2         O3       PM25
# 0  17.5  23.541667  29.633236  38.776073   84.213067   8.860078  23.900000
# 1  11.5  13.920833  39.831732  45.196500  106.270968  15.261562   9.358333
# 2  11.5  10.729167  26.326799  33.294511   73.661705  21.350526   8.900000
# 3  11.5  10.166667  22.848615  31.349600   66.383655  29.200348   6.025000
# 4  11.5  10.762500  33.210684  32.678411   83.600748  23.637889   4.941667
#
# [5 rows x 28 columns]

# %%
daily_data.tail()
# Out:
#       date_time       aqi          co        no       no2         o3  \
# 1090 2023-12-27  1.818182  230.917273  5.883421  7.241364  66.258182
# 1091 2023-12-28  2.000000  228.920000  6.120665  4.790417  80.645000
# 1092 2023-12-29  1.647059  247.983529  6.659092  6.745882  63.953529
# 1093 2023-12-30  1.684211  234.703684  5.908135  6.744211  68.400526
# 1094 2023-12-31  2.000000  228.770769  6.651039  3.950769  70.314615
#
#            so2     pm2_5      pm10       nh3  ...  wind_direction  day  month  \
# 1090  2.767273  2.204545  3.511818  0.156364  ...      184.590909  2.0   12.0
# 1091  1.971667  0.952917  2.398333  0.145000  ...      226.208333  3.0   12.0
# 1092  2.524706  0.590588  0.997059  0.273529  ...      239.352941  4.0   12.0
# 1093  2.351053  0.686316  1.174737  0.205789  ...      206.789474  5.0   12.0
# 1094  1.404615  0.521538  0.743846  0.202308  ...      223.153846  6.0   12.0
#
#            hour       PM10        NO        NO2   NOXasNO2         O3  \
# 1090  10.954545   7.200000  8.268955  16.077438  28.756324  53.993438
# 1091  11.500000  10.475000  3.384937   7.677825  12.867988  74.493472
# 1092  10.352941   5.688235  3.311916  11.224189  16.302389  62.164289
# 1093  10.157895   5.126316  6.518700  14.755066  24.750265  57.303258
# 1094  13.384615   3.538462  2.701066   7.800652  11.942226  71.916118
#
#           PM25
# 1090  5.136364
# 1091  7.041667
# 1092  2.705882
# 1093  3.105263
# 1094  2.538462
#
# [5 rows x 28 columns]

# %%
x = daily_data.date_time.tolist()
y = daily_data.no2.tolist()
y_2 = daily_data.NO2.tolist()
plt.figure(figsize=(14, 6))
plt.plot(x,y, color='blue',label='no2', alpha=0.6)
plt.plot(x,y_2, color='green',label='no2 AQE', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# Observations:
# - The pattern of fluctuations is similar for both sets of data
# - The Air Quality England data is generally much higher than the original API data
# - There is some missing data in 2022 AQE data

# %% [markdown]
# <div class="purple extra-padding">
#     <h3>Visualising NO2 data by month</h3>
# </div>

# %%
monthly_data = temp_df.resample('ME').mean().reset_index()

monthly_data.head()
# Out:
#    date_time       aqi          co         no        no2         o3  \
# 0 2021-01-31  1.301273  275.121330   8.532188  25.992999  33.855955
# 1 2021-02-28  1.469449  270.673159  11.647487  23.553934  50.964121
# 2 2021-03-31  1.939107  276.649905  12.074105  25.722368  54.517264
# 3 2021-04-30  1.938889  266.349833  10.383798  26.771889  64.273208
# 4 2021-05-31  1.331090  208.565195   3.557953  13.770175  62.108306
#
#          so2      pm2_5       pm10       nh3  ...  wind_direction       day  \
# 0  10.896888   5.584965   6.494908  0.762744  ...      193.724187  3.219236
# 1  10.037675   7.769344   9.413353  2.175977  ...      157.687034  3.002981
# 2   9.586184  11.344899  13.432625  1.585196  ...      192.507442  2.803789
# 3  10.496153   8.561708  10.203486  1.550792  ...      129.883333  3.033333
# 4   5.509219   3.783217   4.909515  0.554913  ...      203.487214  3.067295
#
#    month       hour       PM10         NO        NO2    NOXasNO2         O3  \
# 0    1.0  11.588402  15.076803  33.110680  38.570537   89.339537  26.214913
# 1    2.0  11.485842  23.947392  36.285724  42.228218   97.865551  35.254778
# 2    3.0  11.481732  23.708187  30.571302  38.972977   85.848320  40.819368
# 3    4.0  11.500000  24.558056  36.944996  53.513169  110.161372  46.700325
# 4    5.0  11.484522  16.387483  26.480508  43.740905   84.343784  52.251406
#
#         PM25
# 0  11.342008
# 1  13.842623
# 2  16.803248
# 3  12.557639
# 4   9.441723
#
# [5 rows x 28 columns]

# %%
monthly_data.tail()
# Out:
#     date_time       aqi          co        no        no2         o3       so2  \
# 31 2023-08-31  1.481781  222.830378  4.490304  11.896977  52.503539  5.257476
# 32 2023-09-30  2.066461  269.941144  9.741035  22.355039  57.914916  9.139397
# 33 2023-10-31  1.577424  264.118350  7.122721  19.208148  44.547382  6.905847
# 34 2023-11-30  1.472952  263.182828  7.618622  21.641329  40.936800  7.340943
# 35 2023-12-31  1.580808  268.995539  8.214919  18.033182  48.522181  6.704108
#
#         pm2_5       pm10       nh3  ...  wind_direction       day  month  \
# 31   4.988893   6.977233  0.536300  ...      232.503374  2.904184    8.0
# 32  14.424544  18.186167  1.099057  ...      166.000000  3.083462    9.0
# 33   6.277178   8.599566  0.498135  ...      194.780029  2.924747   10.0
# 34   3.760325   4.913709  0.482736  ...      228.448223  2.995363   11.0
# 35   3.580993   5.288316  0.507778  ...      226.562290  3.043771   12.0
#
#          hour       PM10         NO        NO2    NOXasNO2         O3  \
# 31  11.497976  11.095142  14.984498  27.755710   50.731620  36.923746
# 32  11.639876  19.491577  31.781836  53.469898  102.217608  36.186074
# 33  11.684515  13.575181  38.782438  43.698937  103.164511  25.649338
# 34  11.686244  13.124652  36.277448  41.867591   97.492234  26.351452
# 35  11.500000   9.528620  29.654343  33.071134   78.540492  37.199838
#
#          PM25
# 31   7.595816
# 32  10.016229
# 33   6.520984
# 34   6.961360
# 35   6.567340
#
# [5 rows x 28 columns]

# %%
x = monthly_data.date_time.tolist()
y = monthly_data.no2.tolist()
y_2 = monthly_data.NO2.tolist()
plt.figure(figsize=(14, 6))
plt.bar(x,y, color='blue',label='no2')
plt.bar(x,y_2, color='green',label='no2 AQE')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 x = monthly_data.date_time.tolist()
#       2 y = monthly_data.no2.tolist()
#       3 y_2 = monthly_data.NO2.tolist()
#
# NameError: name 'monthly_data' is not defined

# %% [markdown]
# **Observations:**
# - NO2 levels rise in September and peak in winter
# - NO2 levels dip in summer
# - AQE data is a lot higher than API data

# %% [markdown]
# ### Yearly averages for pollutants in Hammersmith

# %%
# Average values per year

yearly_data = temp_df.resample('YE').mean().reset_index()

columns_to_display = ['date_time', 'no2', 'NO2','pm2_5','PM25','pm10','PM10']
yearly_data_selected = yearly_data[columns_to_display]
yearly_data_selected
# Out:
#    date_time        no2        NO2     pm2_5       PM25      pm10       PM10
# 0 2021-12-31  19.942913  44.497764  6.782082  10.871241  8.446464  19.675007
# 1 2022-12-31  18.791182  49.546961  7.125595   9.110175  9.104106  21.509811
# 2 2023-12-31  18.483511  40.771865  6.949437   8.920075  8.911578  17.546360

# %% [markdown]
# **Observations**
# - Average levels of no2 are markedly different according to the different datasets
# - Data from AQE shows that average levels of NO2 are breaching both UK and WHO guidelines
# - Both datasets agree that levels of NO2 have gone down slightly over past 3 years but are still above WHO guidelines
# - Levels of pm2.5 have fluctuated and were higher in 2023 than 2021 according to API data but have gone down slightly according to data from AQE
# - Levels of pm2.5 from both sets of data breach WHO guidelines

# %% [markdown]
# ### Current performance against air quality targets

# %%
NO2_above_UK_target = weather_aq[weather_aq['no2'] >= 40]
NO2_AQE_above_UK_target = weather_aq[weather_aq['NO2'] >= 40]
NO2_above_WHO_target = weather_aq[weather_aq['no2'] >= 10]
NO2_AQE_above_WHO_target= weather_aq[weather_aq['NO2'] >= 10]

# %%
NO2_above_UK_target.no2.describe()
# Out:
# count    2810.000000
# mean       54.844263
# std        13.116045
# min        40.100000
# 25%        45.240000
# 50%        51.410000
# 75%        61.010000
# max       126.120000
# Name: no2, dtype: float64

# %%
NO2_AQE_above_UK_target.NO2.describe()
# Out:
# count    12894.000000
# mean        66.167818
# std         21.319309
# min         40.008810
# 25%         50.827725
# 50%         61.495761
# 75%         75.171220
# max        300.888520
# Name: NO2, dtype: float64

# %%
NO2_above_WHO_target.no2.describe()
# Out:
# count    16385.000000
# mean        25.814989
# std         16.004120
# min         10.020000
# 25%         14.050000
# 50%         20.050000
# 75%         32.900000
# max        126.120000
# Name: no2, dtype: float64

# %%
NO2_AQE_above_WHO_target.NO2.describe()
# Out:
# count    23667.000000
# mean        47.290629
# std         26.574821
# min         10.000430
# 25%         25.897050
# 50%         43.618455
# 75%         63.456020
# max        300.888520
# Name: NO2, dtype: float64

# %%
percentage_exceeding_uk = len(NO2_above_UK_target.no2) / len(weather_aq.no2) * 100
percentage_exceeding_uk
# Out:
# 11.179629998010741

# %%
percentage_exceeding_uk_AQE = len(NO2_AQE_above_UK_target.NO2) / len(weather_aq.NO2) * 100
percentage_exceeding_uk_AQE
# Out:
# 51.29898547841655

# %%
percentage_exceeding_WHO = len(NO2_above_WHO_target.no2)/ len(weather_aq.no2) * 100
percentage_exceeding_WHO
# Out:
# 65.18798488163915

# %%
percentage_exceeding_WHO_AQE = len(NO2_AQE_above_WHO_target.NO2)/ len(weather_aq.NO2) * 100
percentage_exceeding_WHO_AQE
# Out:
# 94.15953849214243

# %% [markdown]
# **In the past 3 years, almost 11% of the air quality recordings at this location exceeded the UK's target for NO2 and more than 64% exceeded the WHO's 2021 air quality guidelines.**

# %%
pm25_above_UK_target = weather_aq[weather_aq['pm2_5'] >= 10]
pm25_above_WHO_target = weather_aq[weather_aq['pm2_5'] >= 5]

# %%
pm25_above_UK_target.pm2_5.describe()
# Out:
# count    4785.000000
# mean       20.133486
# std        11.281232
# min        10.000000
# 25%        12.360000
# 50%        16.230000
# 75%        23.720000
# max       104.540000
# Name: pm2_5, dtype: float64

# %%
pm25_above_WHO_target.pm2_5.describe()
# Out:
# count    10464.000000
# mean        12.988568
# std         10.114056
# min          5.000000
# 25%          6.560000
# 50%          9.340000
# 75%         15.322500
# max        104.540000
# Name: pm2_5, dtype: float64

# %%
percentage_exceeding_uk_pm25 = len(pm25_above_UK_target.pm2_5) / len(weather_aq.pm2_5) * 100
percentage_exceeding_uk_pm25
# Out:
# 19.037199124726477

# %%
percentage_exceeding_WHO_pm25 = len(pm25_above_WHO_target.pm2_5) / len(weather_aq.pm2_5) * 100
percentage_exceeding_WHO_pm25
# Out:
# 41.63119156554605

# %% [markdown]
# 18% of air quality recordings at this station have breached the UK's target for pm2.5 and over 40% have breached WHO guidelines.

# %% [markdown]
# ### Average levels of NO2 for 2023

# %%
start_date = '2023-01-01'
end_date = '2023-12-31'


weather_2023 = weather_aq[weather_aq['date_time'].between(start_date, end_date)]
mean_no2 = statistics.mean(weather_2023.no2)
mean_no2
# Out:
# 18.506333655472336

# %%
median_no2 = statistics.median(weather_2023.no2)
median_no2
# Out:
# 13.02

# %% [markdown]
# ### Average levels of PM2.5 for 2023

# %%
mean_pm25 = statistics.mean(weather_2023.pm2_5)
mean_pm25
# Out:
# 6.959531287750664

# %%
median_pm25 = statistics.median(weather_2023.pm2_5)
median_pm25
# Out:
# 3.85

# %% [markdown]
# **Both the mean and median levels of NO2 and PM2.5 for the last year exceed the WHO's guidelines but are below UK targets.**

# %% [markdown]
# ## Heatmap to show correlation between pollutants and weather

# %%
weather_aq.columns
# Out:
# Index(['date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'temp_C', 'percent_humidity', 'precipitation', 'rain',
#        'snowfall', 'surface_pressure', 'wind_speed_10m', 'wind_speed_100m',
#        'wind_direction', 'day', 'month', 'hour', 'PM10', 'NO', 'NO2',
#        'NOXasNO2', 'O3', 'PM25'],
#       dtype='object')

# %%
# heatmap to look at data on days where no2 is high and find correlations

hm_columns = ['no2', 'o3', 'pm2_5', 'pm10', 'temp_C', 'percent_humidity', 'precipitation', 'surface_pressure', 'wind_speed_10m',
       'wind_direction', 'PM10', 'NO', 'NO2', 'NOXasNO2', 'O3', 'PM25']
heatmap_data = weather_aq[hm_columns]
plt.figure(figsize = (12,12))
# correlation_matrix = high_no2.corr()
correlation_matrix = heatmap_data.corr()
# seaborn adds heatmap to visually highlight significant values in the matrix
sns.heatmap(data = correlation_matrix, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# **The heatmap shows the correlation between different pollutants and the weather.**
# - Each set of data shows slightly different levels of correlation, but some general patterns occur
# - There should be near perfect correlation between the measurements of the same pollutant for each dataset but this is not the case
# - There is a strong correlation between different pollutant levels. Generally when there are high levels of one pollutant, the others are also high (with the exception of ozone)
# - There is little correlation between most pollutants and weather. However there is a small negative correlation between wind speed and pollutants
# - Ozone levels tend to be higher if the temperature is higher and it is more humid
# - There is a near perfect correlation between pm2_5 and pm10. If pm2_5 is high, pm10 is high

# %% [markdown]
# **Why are ozone levels lower when the others are high?**
#
# Photochemical Reactions:
# - Ozone is a secondary pollutant, meaning it is not directly emitted but formed through photochemical reactions in the atmosphere.
# - These reactions typically involve precursor pollutants like nitrogen oxides (NOₓ) and volatile organic compounds (VOCs) in the presence of sunlight.
# - High levels of NO can actually consume ozone through a reaction that converts NO to NO₂ and O₃ to O₂.
#
# Sources and Formation:
# - NOₓ is primarily emitted from combustion processes, such as vehicle exhaust and industrial activities.
# - Ozone formation is more pronounced in sunny conditions, which means its levels can be higher in rural areas downwind of urban centers (where precursor pollutants have had time to react).
#
# Temporal Patterns:
# - There are often diurnal and seasonal patterns in the levels of these pollutants.
# - For instance, NO levels are typically higher during rush hours due to traffic emissions, while ozone levels peak in the afternoon when sunlight is most intense.

# %% [markdown]
# ## Correlation between time of day and pollutant levels

# %% [markdown]
# ### NO2

# %%
high_no2 = weather_aq[weather_aq['no2'] > 40]
high_no2_2 = weather_aq[weather_aq['NO2'] > 40]
high_no2_by_hour = high_no2.groupby('hour').no2.count().to_frame()
high_no2_by_hour_2 = high_no2_2.groupby('hour').NO2.count().to_frame()
x = high_no2_by_hour.index.tolist()
y = high_no2_by_hour.no2.tolist()
y_2 = high_no2_by_hour_2.NO2.tolist()

fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plot the first bar chart
axs[0].bar(x, y, alpha=0.6)
axs[0].set_xticks(x)
axs[0].set_xticklabels([str(hour) for hour in x])
axs[0].set_xlabel('Hour of the Day')
axs[0].set_ylabel('Count of High NO2 Readings')
axs[0].set_title('High NO2 Readings by Hour - API data')

# Plot the second bar chart
axs[1].bar(x, y_2, alpha=0.6)
axs[1].set_xticks(x)
axs[1].set_xticklabels([str(hour) for hour in x])
axs[1].set_xlabel('Hour of the Day')
axs[1].set_ylabel('Count of High NO2 Readings')
axs[1].set_title('High NO2 Readings by Hour - Air Quality England')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# This bar chart shows which times of day the UK limit for no2 is most frequently breached.
# There is a peak between 7 and 10 and a larger peak between 5pm and midnight.

# %% [markdown]
# ### Average no2 readings by the hour

# %%
average_by_hour = weather_aq.groupby('hour').no2.mean().to_frame()
average_by_hour_2 = weather_aq.groupby('hour').NO2.mean().to_frame()
x = average_by_hour.index.tolist()
y = average_by_hour.no2.tolist()
y_2 = average_by_hour_2.NO2.tolist()
plt.figure(figsize=(14, 6))
plt.plot(x, y, label='API data')
plt.plot(x,y_2, color='green', label='AQE data')
plt.xticks(ticks=x, labels=[str(hour) for hour in x])

plt.xlabel('Hour of the Day')
plt.ylabel('Average NO2 Readings')
plt.title('Average NO2 Readings by hour')
plt.legend()
# Show plot
plt.show()

# %% [markdown]
# ### PM2.5

# %%
high_PM25 = weather_aq[weather_aq['pm2_5'] > 10]
high_PM25_2 = weather_aq[weather_aq['PM25'] > 10]
high_pm25_by_hour = high_PM25.groupby('hour').pm2_5.count().to_frame()
high_pm25_by_hour_2 = high_PM25_2.groupby('hour').PM25.count().to_frame()
x = high_pm25_by_hour.index.tolist()
y = high_pm25_by_hour.pm2_5.tolist()
y_2 = high_pm25_by_hour_2.PM25.tolist()

fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plot the first bar chart
axs[0].bar(x, y, alpha=0.6)
axs[0].set_xticks(x)
axs[0].set_xticklabels([str(hour) for hour in x])
axs[0].set_xlabel('Hour of the Day')
axs[0].set_ylabel('Count of High PM2.5 Readings')
axs[0].set_title('High NO2 Readings by Hour - API data')

# Plot the second bar chart
axs[1].bar(x, y_2, alpha=0.6)
axs[1].set_xticks(x)
axs[1].set_xticklabels([str(hour) for hour in x])
axs[1].set_xlabel('Hour of the Day')
axs[1].set_ylabel('Count of High PM2.5 Readings')
axs[1].set_title('High NO2 Readings by Hour - Air Quality England')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Average no2 readings by the hour

# %%
average_by_hour = weather_aq.groupby('hour').pm2_5.mean().to_frame()
average_by_hour_2 = weather_aq.groupby('hour').PM25.mean().to_frame()
x = average_by_hour.index.tolist()
y = average_by_hour.pm2_5.tolist()
y_2 = average_by_hour_2.PM25.tolist()
plt.figure(figsize=(14, 6))
plt.plot(x, y, label="API data")
plt.plot(x, y_2, color='green', label="AQE data")
plt.xticks(ticks=x, labels=[str(hour) for hour in x])

plt.xlabel('Hour of the Day')
plt.ylabel('Average PM2.5 Readings')
plt.title('Average PM2.5 Readings by hour')
plt.legend()
# Show plot
plt.show()

# %% [markdown]
# ## Correlation between month and pollutant levels

# %%
average_by_month = weather_aq.groupby('month').no2.mean().to_frame()
average_by_month_2 = weather_aq.groupby('month').NO2.mean().to_frame()
x = average_by_month.index.tolist()
y = average_by_month.no2.tolist()
y_2 = average_by_month_2.NO2.tolist()
fig, axs = plt.subplots(2, 1, figsize=(14, 12))

# Plot the first bar chart
axs[0].bar(x, y, alpha=0.6)
axs[0].set_xticks(x)
axs[0].set_xticklabels([str(month) for month in x])
axs[0].set_xlabel('Month')
axs[0].set_ylabel('Average NO2 Readings')
axs[0].set_title('High NO2 Readings by Month - API data')

# Plot the second bar chart
axs[1].bar(x, y_2, alpha=0.6)
axs[1].set_xticks(x)
axs[1].set_xticklabels([str(month) for month in x])
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Average NO2 Readings')
axs[1].set_title('High NO2 Readings by Month - Air Quality England')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# **Summary**
# - API pollutant levels are lower and show a dip during summer months
# - Average levels from AQE show a bre
# - This could be linked to school holidays as well as more people driving when weather is colder (cannot only be school holidays as May and June also lower)
# - How can we encourage less car use in the winter months?

# %% [markdown]
# ## Correlation between day of the week and pollutant levels

# %%
high_no2 = weather_aq[weather_aq['no2'] > 40]

high_no2_by_day = high_no2.groupby('day').no2.count().to_frame()
x = high_no2_by_day.index.tolist()
y = high_no2_by_day.no2.tolist()

plt.figure(figsize=(14, 6))
plt.bar(x, y)

days = ['Mon','Tues','Weds', 'Thurs', 'Fri', 'Sat', 'Sun']
plt.xticks(ticks=x, labels=[str(day) for day in days])


plt.xlabel('Day of the Week')
plt.ylabel('Count of High NO2 Readings')
plt.title('High NO2 Readings by Day')


plt.show()

# %%
average_no2_by_day = weather_aq.groupby('day').no2.mean().to_frame()
x = average_no2_by_day.index.tolist()
y = average_no2_by_day.no2.tolist()

plt.figure(figsize=(14, 6))
plt.bar(x, y)

plt.xticks(ticks=x, labels=[str(day) for day in days])

plt.xlabel('Day of the Week')
plt.ylabel('Average NO2 Readings μg/m³')
plt.title('Average NO2 Readings by Day')


plt.show()

# %% [markdown]
# WHO recommended levels are 10 μg/m³, UK recommended levels are 40μg/m³.

# %% [markdown]
# ## Correlation between temperature and pollutant levels

# %%
# Look at correlation in 2023 and just where pollutant levels are high so that graphs are easier to read.
weather_2023 = weather_aq[(weather_aq['date_time'] >= '2023-01-01') & (weather_aq['date_time'] <= '2023-12-01')&(weather_aq.no2>=40)]
x = weather_2023.temp_C.tolist()
y_1 = weather_2023.no2.tolist()


plt.scatter(x,y_1)
plt.show()

# %%
weather_2023 = weather_aq[(weather_aq['date_time'] >= '2023-01-01') & (weather_aq['date_time'] <= '2023-12-01')&(weather_aq.o3>=100)]
x = weather_2023.temp_C.tolist()
y_2 = weather_2023.o3.tolist()
plt.scatter(x,y_2)
plt.show()

# %%
weather_2023 = weather_aq[(weather_aq['date_time'] >= '2023-01-01') & (weather_aq['date_time'] <= '2023-12-01')&(weather_aq.pm2_5>=15)]
x = weather_2023.temp_C.tolist()
y_3 = weather_2023.pm2_5.tolist()
plt.scatter(x,y_3)
plt.show()

# %%
weather_2023 = weather_aq[(weather_aq['date_time'] >= '2023-01-01') & (weather_aq['date_time'] <= '2023-12-01')&(weather_aq.pm10>=45)]
x = weather_2023.temp_C.tolist()
y_3 = weather_2023.pm10.tolist()
plt.scatter(x,y_3)
plt.show()

# %% [markdown]
# NB: There are no instances where co levels breach the WHO guidelines of 4000mg/m3 so there is no visualisation for this pollutant.

# %% [markdown]
# **Analysis**
#
# - There are 2 peaks for pm2, pm10 and no2, both at high and low temperatures. This could be due to more cars being on the road in lower temperatures
# - Generally ozone levels go up as the temperature increases (as we saw from the heatmap)

# %% [markdown]
# ## Analysis of traffic data (data obtained from Department for transport)

# %% [markdown]
# https://roadtraffic.dft.gov.uk/manualcountpoints/48146

# %%
traffic_data = pd.read_csv('../data_unclean/traffic_data_2021.csv')
traffic_data.head(10)
# Out:
#    count_point_id direction_of_travel  year  count_date  hour  region_id  \
# 0           48146                   E  2021  2021-11-02     7          6
# 1           48146                   E  2021  2021-11-02     8          6
# 2           48146                   E  2021  2021-11-02     9          6
# 3           48146                   E  2021  2021-11-02    10          6
# 4           48146                   E  2021  2021-11-02    11          6
# 5           48146                   E  2021  2021-11-02    12          6
# 6           48146                   E  2021  2021-11-02    13          6
# 7           48146                   E  2021  2021-11-02    14          6
# 8           48146                   E  2021  2021-11-02    15          6
# 9           48146                   E  2021  2021-11-02    16          6
#
#   region_name  local_authority_id    local_authority_name road_name  ...  \
# 0      London                 146  Hammersmith and Fulham      A306  ...
# 1      London                 146  Hammersmith and Fulham      A306  ...
# 2      London                 146  Hammersmith and Fulham      A306  ...
# 3      London                 146  Hammersmith and Fulham      A306  ...
# 4      London                 146  Hammersmith and Fulham      A306  ...
# 5      London                 146  Hammersmith and Fulham      A306  ...
# 6      London                 146  Hammersmith and Fulham      A306  ...
# 7      London                 146  Hammersmith and Fulham      A306  ...
# 8      London                 146  Hammersmith and Fulham      A306  ...
# 9      London                 146  Hammersmith and Fulham      A306  ...
#
#   buses_and_coaches lgvs hgvs_2_rigid_axle  hgvs_3_rigid_axle  \
# 0                30  227                46                  4
# 1                22  204                40                  5
# 2                18  174                48                  4
# 3                21  127                45                  1
# 4                18  147                34                  3
# 5                18  124                27                  0
# 6                24  106                27                  1
# 7                17   70                18                  1
# 8                22   80                10                  0
# 9                26   79                 6                  0
#
#    hgvs_4_or_more_rigid_axle  hgvs_3_or_4_articulated_axle  \
# 0                          8                             1
# 1                          7                             3
# 2                         14                             0
# 3                         10                             1
# 4                         10                             0
# 5                         12                             2
# 6                          9                             1
# 7                          5                             0
# 8                          6                             2
# 9                          6                             0
#
#    hgvs_5_articulated_axle  hgvs_6_articulated_axle  all_hgvs  \
# 0                        0                        3        62
# 1                        0                        3        58
# 2                        0                        4        70
# 3                        0                        5        62
# 4                        1                        2        50
# 5                        1                        1        43
# 6                        1                        3        42
# 7                        0                        0        24
# 8                        0                        0        18
# 9                        0                        0        12
#
#    all_motor_vehicles
# 0                1054
# 1                1112
# 2                1121
# 3                 896
# 4                 906
# 5                 773
# 6                 744
# 7                 599
# 8                 654
# 9                 766
#
# [10 rows x 32 columns]

# %%
traffic_data.columns
# Out:
# Index(['count_point_id', 'direction_of_travel', 'year', 'count_date', 'hour',
#        'region_id', 'region_name', 'local_authority_id',
#        'local_authority_name', 'road_name', 'road_type',
#        'start_junction_road_name', 'end_junction_road_name', 'easting',
#        'northing', 'latitude', 'longitude', 'link_length_km',
#        'link_length_miles', 'pedal_cycles', 'two_wheeled_motor_vehicles',
#        'cars_and_taxis', 'buses_and_coaches', 'lgvs', 'hgvs_2_rigid_axle',
#        'hgvs_3_rigid_axle', 'hgvs_4_or_more_rigid_axle',
#        'hgvs_3_or_4_articulated_axle', 'hgvs_5_articulated_axle',
#        'hgvs_6_articulated_axle', 'all_hgvs', 'all_motor_vehicles'],
#       dtype='object')

# %%
traffic_data = traffic_data.drop(columns =['count_point_id','direction_of_travel', 'year','region_id', 'region_name', 'local_authority_id',
       'local_authority_name', 'road_name', 'road_type', 'start_junction_road_name', 'end_junction_road_name', 'easting',
       'northing', 'latitude', 'longitude', 'link_length_km',
       'link_length_miles'])

# %%
traffic_data.head(10)
# Out:
#    count_date  hour  pedal_cycles  two_wheeled_motor_vehicles  cars_and_taxis  \
# 0  2021-11-02     7            94                          60             675
# 1  2021-11-02     8           144                          61             767
# 2  2021-11-02     9            57                          34             825
# 3  2021-11-02    10            19                          35             651
# 4  2021-11-02    11            21                          27             664
# 5  2021-11-02    12            14                          26             562
# 6  2021-11-02    13            19                          30             542
# 7  2021-11-02    14            14                          30             458
# 8  2021-11-02    15            16                          20             514
# 9  2021-11-02    16            24                          26             623
#
#    buses_and_coaches  lgvs  hgvs_2_rigid_axle  hgvs_3_rigid_axle  \
# 0                 30   227                 46                  4
# 1                 22   204                 40                  5
# 2                 18   174                 48                  4
# 3                 21   127                 45                  1
# 4                 18   147                 34                  3
# 5                 18   124                 27                  0
# 6                 24   106                 27                  1
# 7                 17    70                 18                  1
# 8                 22    80                 10                  0
# 9                 26    79                  6                  0
#
#    hgvs_4_or_more_rigid_axle  hgvs_3_or_4_articulated_axle  \
# 0                          8                             1
# 1                          7                             3
# 2                         14                             0
# 3                         10                             1
# 4                         10                             0
# 5                         12                             2
# 6                          9                             1
# 7                          5                             0
# 8                          6                             2
# 9                          6                             0
#
#    hgvs_5_articulated_axle  hgvs_6_articulated_axle  all_hgvs  \
# 0                        0                        3        62
# 1                        0                        3        58
# 2                        0                        4        70
# 3                        0                        5        62
# 4                        1                        2        50
# 5                        1                        1        43
# 6                        1                        3        42
# 7                        0                        0        24
# 8                        0                        0        18
# 9                        0                        0        12
#
#    all_motor_vehicles
# 0                1054
# 1                1112
# 2                1121
# 3                 896
# 4                 906
# 5                 773
# 6                 744
# 7                 599
# 8                 654
# 9                 766

# %%
traffic_data.count_date = pd.to_datetime(traffic_data.count_date)

# %%
traffic_data['date_time'] = traffic_data.apply(lambda row: pd.Timestamp(row['count_date']) + pd.Timedelta(hours=row['hour']), axis=1)

# %%
traffic_aq = pd.merge(traffic_data, weather_aq, left_on=['date_time'], right_on=['date_time'], how='left')

# %%
traffic_aq.head(20)
# Out:
#    count_date  hour_x  pedal_cycles  two_wheeled_motor_vehicles  \
# 0  2021-11-02       7            94                          60
# 1  2021-11-02       8           144                          61
# 2  2021-11-02       9            57                          34
# 3  2021-11-02      10            19                          35
# 4  2021-11-02      11            21                          27
# 5  2021-11-02      12            14                          26
# 6  2021-11-02      13            19                          30
# 7  2021-11-02      14            14                          30
# 8  2021-11-02      15            16                          20
# 9  2021-11-02      16            24                          26
# 10 2021-11-02      17            28                          32
# 11 2021-11-02      18            13                          24
# 12 2021-11-02       7             5                          11
# 13 2021-11-02       8            17                          24
# 14 2021-11-02       9             8                          12
# 15 2021-11-02      10             4                          20
# 16 2021-11-02      11             5                          12
# 17 2021-11-02      12             7                          19
# 18 2021-11-02      13             5                          28
# 19 2021-11-02      14             6                          23
#
#     cars_and_taxis  buses_and_coaches  lgvs  hgvs_2_rigid_axle  \
# 0              675                 30   227                 46
# 1              767                 22   204                 40
# 2              825                 18   174                 48
# 3              651                 21   127                 45
# 4              664                 18   147                 34
# 5              562                 18   124                 27
# 6              542                 24   106                 27
# 7              458                 17    70                 18
# 8              514                 22    80                 10
# 9              623                 26    79                  6
# 10             712                 26    77                 13
# 11             680                 27    44                 10
# 12             701                 24   101                 20
# 13             648                 22    89                 19
# 14             490                 21   105                 33
# 15             529                 14   143                 42
# 16             554                 14   157                 43
# 17             567                 21   165                 45
# 18             608                 15   189                 54
# 19             558                 16   171                 28
#
#     hgvs_3_rigid_axle  hgvs_4_or_more_rigid_axle  ...  precipitation  rain  \
# 0                   4                          8  ...            0.0   0.0
# 1                   5                          7  ...            0.0   0.0
# 2                   4                         14  ...            0.0   0.0
# 3                   1                         10  ...            0.0   0.0
# 4                   3                         10  ...            0.0   0.0
# 5                   0                         12  ...            0.0   0.0
# 6                   1                          9  ...            0.0   0.0
# 7                   1                          5  ...            0.0   0.0
# 8                   0                          6  ...            0.0   0.0
# 9                   0                          6  ...            0.0   0.0
# 10                  0                          0  ...            0.0   0.0
# 11                  0                          0  ...            0.0   0.0
# 12                  1                          2  ...            0.0   0.0
# 13                  1                          0  ...            0.0   0.0
# 14                  3                          8  ...            0.0   0.0
# 15                  1                          4  ...            0.0   0.0
# 16                  4                          7  ...            0.0   0.0
# 17                  3                          0  ...            0.0   0.0
# 18                  6                          8  ...            0.0   0.0
# 19                  3                          9  ...            0.0   0.0
#
#     snowfall  surface_pressure  wind_speed_10m wind_speed_100m  \
# 0        0.0             997.2             8.9            15.9
# 1        0.0             997.5             7.9            15.0
# 2        0.0             997.7             6.7            12.4
# 3        0.0             997.8             7.1             9.3
# 4        0.0             997.8             7.4             9.3
# 5        0.0             998.1             8.0             9.8
# 6        0.0             997.8             7.4             9.2
# 7        0.0             997.7             6.0             7.9
# 8        0.0             997.6             4.7             6.2
# 9        0.0             997.6             5.2             5.8
# 10       0.0             998.0             5.4             5.8
# 11       0.0             998.5             4.4             5.0
# 12       0.0             997.2             8.9            15.9
# 13       0.0             997.5             7.9            15.0
# 14       0.0             997.7             6.7            12.4
# 15       0.0             997.8             7.1             9.3
# 16       0.0             997.8             7.4             9.3
# 17       0.0             998.1             8.0             9.8
# 18       0.0             997.8             7.4             9.2
# 19       0.0             997.7             6.0             7.9
#
#     wind_direction  day  month  hour_y
# 0              249    1     11       7
# 1              240    1     11       8
# 2              234    1     11       9
# 3              240    1     11      10
# 4              241    1     11      11
# 5              252    1     11      12
# 6              247    1     11      13
# 7              253    1     11      14
# 8              247    1     11      15
# 9              236    1     11      16
# 10             274    1     11      17
# 11             261    1     11      18
# 12             249    1     11       7
# 13             240    1     11       8
# 14             234    1     11       9
# 15             240    1     11      10
# 16             241    1     11      11
# 17             252    1     11      12
# 18             247    1     11      13
# 19             253    1     11      14
#
# [20 rows x 37 columns]

# %%
traffic_aq.columns
# Out:
# Index(['count_date', 'hour_x', 'pedal_cycles', 'two_wheeled_motor_vehicles',
#        'cars_and_taxis', 'buses_and_coaches', 'lgvs', 'hgvs_2_rigid_axle',
#        'hgvs_3_rigid_axle', 'hgvs_4_or_more_rigid_axle',
#        'hgvs_3_or_4_articulated_axle', 'hgvs_5_articulated_axle',
#        'hgvs_6_articulated_axle', 'all_hgvs', 'all_motor_vehicles',
#        'date_time', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
#        'nh3', 'temp_C', 'percent_humidity', 'precipitation', 'rain',
#        'snowfall', 'surface_pressure', 'wind_speed_10m', 'wind_speed_100m',
#        'wind_direction', 'day', 'month', 'hour_y'],
#       dtype='object')

# %%
traffic_aq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   count_date                    24 non-null     datetime64[ns]
#  1   hour_x                        24 non-null     int64
#  2   pedal_cycles                  24 non-null     int64
#  3   two_wheeled_motor_vehicles    24 non-null     int64
#  4   cars_and_taxis                24 non-null     int64
#  5   buses_and_coaches             24 non-null     int64
#  6   lgvs                          24 non-null     int64
#  7   hgvs_2_rigid_axle             24 non-null     int64
#  8   hgvs_3_rigid_axle             24 non-null     int64
#  9   hgvs_4_or_more_rigid_axle     24 non-null     int64
#  10  hgvs_3_or_4_articulated_axle  24 non-null     int64
#  11  hgvs_5_articulated_axle       24 non-null     int64
#  12  hgvs_6_articulated_axle       24 non-null     int64
#  13  all_hgvs                      24 non-null     int64
#  14  all_motor_vehicles            24 non-null     int64
#  15  date_time                     24 non-null     datetime64[ns]
#  16  aqi                           24 non-null     int64
#  17  co                            24 non-null     float64
#  18  no                            24 non-null     float64
#  19  no2                           24 non-null     float64
#  20  o3                            24 non-null     float64
#  21  so2                           24 non-null     float64
#  22  pm2_5                         24 non-null     float64
#  23  pm10                          24 non-null     float64
#  24  nh3                           24 non-null     float64
#  25  temp_C                        24 non-null     float64
#  26  percent_humidity              24 non-null     int64
#  27  precipitation                 24 non-null     float64
#  28  rain                          24 non-null     float64
#  29  snowfall                      24 non-null     float64
#  30  surface_pressure              24 non-null     float64
#  31  wind_speed_10m                24 non-null     float64
#  32  wind_speed_100m               24 non-null     float64
#  33  wind_direction                24 non-null     int64
#  34  day                           24 non-null     int32
#  35  month                         24 non-null     int32
#  36  hour_y                        24 non-null     int32
# dtypes: datetime64[ns](2), float64(15), int32(3), int64(17)
# memory usage: 6.8 KB

# %% [markdown]
# ## Visualisation of traffic and pollutant data

# %% [markdown]
# Note: this dataset is limited to one day, so cannot generalise.

# %%
traffic_data_by_hour = traffic_aq.groupby('hour_x').all_motor_vehicles.sum()
traffic_data_by_hour = traffic_data_by_hour.to_frame().reset_index()
traffic_data_by_hour = pd.merge(traffic_data_by_hour, traffic_aq, left_on='hour_x', right_on='hour_x', how='left')
traffic_data_by_hour.columns
# Out:
# Index(['hour_x', 'all_motor_vehicles_x', 'count_date', 'pedal_cycles',
#        'two_wheeled_motor_vehicles', 'cars_and_taxis', 'buses_and_coaches',
#        'lgvs', 'hgvs_2_rigid_axle', 'hgvs_3_rigid_axle',
#        'hgvs_4_or_more_rigid_axle', 'hgvs_3_or_4_articulated_axle',
#        'hgvs_5_articulated_axle', 'hgvs_6_articulated_axle', 'all_hgvs',
#        'all_motor_vehicles_y', 'date_time', 'aqi', 'co', 'no', 'no2', 'o3',
#        'so2', 'pm2_5', 'pm10', 'nh3', 'temp_C', 'percent_humidity',
#        'precipitation', 'rain', 'snowfall', 'surface_pressure',
#        'wind_speed_10m', 'wind_speed_100m', 'wind_direction', 'day', 'month',
#        'hour_y'],
#       dtype='object')

# %%
x = traffic_data_by_hour['hour_x']
y_traffic = traffic_data_by_hour['all_motor_vehicles_y']
y_no2 = traffic_data_by_hour['no2']
y_so2 = traffic_data_by_hour['so2']
y_pm2_5 = traffic_data_by_hour['pm2_5']
y_nh3 = traffic_data_by_hour['nh3']
y_temp = traffic_data_by_hour['temp_C']
y_o3 = traffic_data_by_hour['o3']

fig, ax1 = plt.subplots(figsize=(12, 8))

palette = sns.color_palette()

line1 = sns.lineplot(x=x, y=y_traffic, ax=ax1, color=palette[0], label='', errorbar=None)

ax1.set_xlabel('Hour of the Day')
ax1.set_ylabel('Number of Vehicles', color=palette[0])
ax1.tick_params(axis='y', labelcolor=palette[0])

# Create y-axes for each pollutant
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()
ax5 = ax1.twinx()
ax6 = ax1.twinx()
ax7 = ax1.twinx()

# Offset the right spine of ax3, ax4, ax5, and ax6
ax3.spines['right'].set_position(('outward', 50))
ax4.spines['right'].set_position(('outward', 100))
ax5.spines['right'].set_position(('outward', 150))
ax6.spines['right'].set_position(('outward', 200))
ax7.spines['right'].set_position(('outward', 250))

# Plot each pollutant line and store the line objects
line2 = sns.lineplot(x=x, y=y_no2, ax=ax2, color=palette[1], label='', errorbar=None)
line3 = sns.lineplot(x=x, y=y_so2, ax=ax3, color=palette[2], label='', errorbar=None)
line4 = sns.lineplot(x=x, y=y_pm2_5, ax=ax4, color=palette[3], label='', errorbar=None)
line5 = sns.lineplot(x=x, y=y_nh3, ax=ax5, color=palette[4], label='', errorbar=None)
line6 = sns.lineplot(x=x, y=y_temp, ax=ax6, color=palette[5], label='', errorbar=None)
line7 = sns.lineplot(x=x,y=y_o3, ax=ax7, color=palette[6], label='', errorbar=None)

# Setting labels and colors for each y-axis
ax2.set_ylabel('NO2 (µg/m³)', color=palette[1])
ax2.tick_params(axis='y', labelcolor=palette[1])

ax3.set_ylabel('SO2 (µg/m³)', color=palette[2])
ax3.tick_params(axis='y', labelcolor=palette[2])

ax4.set_ylabel('PM2.5 (µg/m³)', color=palette[3])
ax4.tick_params(axis='y', labelcolor=palette[3])

ax5.set_ylabel('NH3 (µg/m³)', color=palette[4])
ax5.tick_params(axis='y', labelcolor=palette[4])

ax6.set_ylabel('Temperature (°C)', color=palette[5])
ax6.tick_params(axis='y', labelcolor=palette[5])

ax7.set_ylabel('o3 (µg/m³)', color=palette[6])
ax7.tick_params(axis='y', labelcolor=palette[6])

# Create a custom legend
lines = [line1.lines[0], line2.lines[0], line3.lines[0], line4.lines[0], line5.lines[0], line6.lines[0]]
labels = ['Traffic', 'NO2', 'SO2', 'PM2.5', 'NH3', 'Temperature', 'o3']

fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# - There is a peak dip in traffic in the middle of the day (at approx 2pm) which causes levels of pollutants (apart from ozone) to drop.
#
#
# **Potential advice for schools:**
# - Keep windows closed wherever possible until 10:00 and after 14:00
# - Playtimes and lunchtimes when children are outside should happen between 10 and 14:00
# - Take other measures to reduce air pollution (e.g. indoor plants, outdoor planting, air purifiers)

# %% [markdown]
# ### Analysing vehicle types throughout day

# %%
traffic_data_by_hour.iloc[:,:17]
# Out:
#     hour_x  all_motor_vehicles_x count_date  pedal_cycles  \
# 0        7                  1917 2021-11-02            94
# 1        7                  1917 2021-11-02             5
# 2        8                  1916 2021-11-02           144
# 3        8                  1916 2021-11-02            17
# 4        9                  1796 2021-11-02            57
# 5        9                  1796 2021-11-02             8
# 6       10                  1653 2021-11-02            19
# 7       10                  1653 2021-11-02             4
# 8       11                  1704 2021-11-02            21
# 9       11                  1704 2021-11-02             5
# 10      12                  1600 2021-11-02            14
# 11      12                  1600 2021-11-02             7
# 12      13                  1656 2021-11-02            19
# 13      13                  1656 2021-11-02             5
# 14      14                  1413 2021-11-02            14
# 15      14                  1413 2021-11-02             6
# 16      15                  1704 2021-11-02            16
# 17      15                  1704 2021-11-02            15
# 18      16                  1628 2021-11-02            24
# 19      16                  1628 2021-11-02            23
# 20      17                  1764 2021-11-02            28
# 21      17                  1764 2021-11-02            26
# 22      18                  1559 2021-11-02            13
# 23      18                  1559 2021-11-02            42
#
#     two_wheeled_motor_vehicles  cars_and_taxis  buses_and_coaches  lgvs  \
# 0                           60             675                 30   227
# 1                           11             701                 24   101
# 2                           61             767                 22   204
# 3                           24             648                 22    89
# 4                           34             825                 18   174
# 5                           12             490                 21   105
# 6                           35             651                 21   127
# 7                           20             529                 14   143
# 8                           27             664                 18   147
# 9                           12             554                 14   157
# 10                          26             562                 18   124
# 11                          19             567                 21   165
# 12                          30             542                 24   106
# 13                          28             608                 15   189
# 14                          30             458                 17    70
# 15                          23             558                 16   171
# 16                          20             514                 22    80
# 17                          28             756                 29   193
# 18                          26             623                 26    79
# 19                          42             601                 19   169
# 20                          32             712                 26    77
# 21                          51             700                 24   110
# 22                          24             680                 27    44
# 23                          58             616                 35    54
#
#     hgvs_2_rigid_axle  hgvs_3_rigid_axle  hgvs_4_or_more_rigid_axle  \
# 0                  46                  4                          8
# 1                  20                  1                          2
# 2                  40                  5                          7
# 3                  19                  1                          0
# 4                  48                  4                         14
# 5                  33                  3                          8
# 6                  45                  1                         10
# 7                  42                  1                          4
# 8                  34                  3                         10
# 9                  43                  4                          7
# 10                 27                  0                         12
# 11                 45                  3                          0
# 12                 27                  1                          9
# 13                 54                  6                          8
# 14                 18                  1                          5
# 15                 28                  3                          9
# 16                 10                  0                          6
# 17                 37                  0                          5
# 18                  6                  0                          6
# 19                 25                  2                          3
# 20                 13                  0                          0
# 21                 18                  0                          0
# 22                 10                  0                          0
# 23                  7                  0                          2
#
#     hgvs_3_or_4_articulated_axle  hgvs_5_articulated_axle  \
# 0                              1                        0
# 1                              0                        1
# 2                              3                        0
# 3                              0                        1
# 4                              0                        0
# 5                              2                        1
# 6                              1                        0
# 7                              0                        1
# 8                              0                        1
# 9                              4                        0
# 10                             2                        1
# 11                             3                        2
# 12                             1                        1
# 13                             3                        1
# 14                             0                        0
# 15                             1                        1
# 16                             2                        0
# 17                             1                        1
# 18                             0                        0
# 19                             0                        1
# 20                             0                        0
# 21                             0                        1
# 22                             0                        2
# 23                             0                        0
#
#     hgvs_6_articulated_axle  all_hgvs  all_motor_vehicles_y  \
# 0                         3        62                  1054
# 1                         2        26                   863
# 2                         3        58                  1112
# 3                         0        21                   804
# 4                         4        70                  1121
# 5                         0        47                   675
# 6                         5        62                   896
# 7                         3        51                   757
# 8                         2        50                   906
# 9                         3        61                   798
# 10                        1        43                   773
# 11                        2        55                   827
# 12                        3        42                   744
# 13                        0        72                   912
# 14                        0        24                   599
# 15                        4        46                   814
# 16                        0        18                   654
# 17                        0        44                  1050
# 18                        0        12                   766
# 19                        0        31                   862
# 20                        0        13                   860
# 21                        0        19                   904
# 22                        0        12                   787
# 23                        0         9                   772
#
#              date_time
# 0  2021-11-02 07:00:00
# 1  2021-11-02 07:00:00
# 2  2021-11-02 08:00:00
# 3  2021-11-02 08:00:00
# 4  2021-11-02 09:00:00
# 5  2021-11-02 09:00:00
# 6  2021-11-02 10:00:00
# 7  2021-11-02 10:00:00
# 8  2021-11-02 11:00:00
# 9  2021-11-02 11:00:00
# 10 2021-11-02 12:00:00
# 11 2021-11-02 12:00:00
# 12 2021-11-02 13:00:00
# 13 2021-11-02 13:00:00
# 14 2021-11-02 14:00:00
# 15 2021-11-02 14:00:00
# 16 2021-11-02 15:00:00
# 17 2021-11-02 15:00:00
# 18 2021-11-02 16:00:00
# 19 2021-11-02 16:00:00
# 20 2021-11-02 17:00:00
# 21 2021-11-02 17:00:00
# 22 2021-11-02 18:00:00
# 23 2021-11-02 18:00:00

# %%
plt.figure(figsize=(14, 10))
x = traffic_data_by_hour['hour_x'].tolist()

# plt.xticks(ticks=x, labels=[str(hour) for hour in x])

y_motorcycles = traffic_data_by_hour['two_wheeled_motor_vehicles'].tolist()
y_lgvs = traffic_data_by_hour['lgvs'].tolist()
y_hgvs = traffic_data_by_hour['all_hgvs'].tolist()
y_bus_coach = traffic_data_by_hour['buses_and_coaches'].tolist()
y_cars_taxis = traffic_data_by_hour['cars_and_taxis'].tolist()
y_total = traffic_data_by_hour['all_motor_vehicles_y'].tolist() 


plt.plot([],[],color='k', label='Motorcycles', linewidth=5)
plt.plot([],[],color='c', label='LGVs', linewidth=5)
plt.plot([],[],color='y', label='HGVs', linewidth=5)
plt.plot([],[],color='m', label='Buses and Coaches', linewidth=5)
plt.plot([],[],color='b', label='Cars and Taxis', linewidth=5)

plt.stackplot(x, y_motorcycles, y_lgvs, y_hgvs, y_bus_coach, y_cars_taxis, colors=['k','c','y','m','b'])

plt.xlabel('Days')
plt.ylabel('Number of vehicles')
plt.title('Number of vehicle by type')

plt.legend()

# %% [markdown]
# - Majority of vehicles are cars and taxis
# - There is a rise in vehicle use at start and end of day (probably for rush hour)

# %% [markdown]
# **Next steps:**
# - look at more road traffic data and look at correlation between more traffic/higher pollutants
# - Finish comparing alternative data for hammersmith and checking high values are reliable

# %%
# This would be good to do if we can gather more road traffic data but currently too limited

# # heatmap to look at correlation between vehicle types and pollutants

# heatmap_data = traffic_data_by_hour.drop(columns=['count_date','date_time', 'temp_C', 'percent_humidity',
#        'precipitation', 'rain', 'snowfall', 'surface_pressure',
#        'wind_speed_10m', 'wind_speed_100m', 'wind_direction', 'day', 'month',
#        'hour_y'])
# plt.figure(figsize = (15,15))
# # correlation_matrix = high_no2.corr()
# correlation_matrix = heatmap_data.corr()
# # seaborn adds heatmap to visually highlight significant values in the matrix
# sns.heatmap(data = correlation_matrix, annot = True)
